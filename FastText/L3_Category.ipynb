# %%
# !pip install fasttext

# %%
# !pip install nltk

# %%
# Mounting Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# importing libraries
import pandas as pd
import numpy as np
import re

# %%
# Load the dataset
df = pd.read_csv('../Datasets/fsa_prod_dump.csv', on_bad_lines='skip')
df.head()
# Out:
#   L0_Category            L1_Class                    L2_Category  \
# 0         NaN                 NaN                            NaN
# 1        Food  Food - Meat & Game        Beef -- Ground & Shapes
# 2        Food  Food - Meat & Game  Beef - Foodservice Whole Cuts
# 3        Food  Food - Meat & Game        Beef Deli & Charcuterie
# 4        Food  Food - Meat & Game        Beef Deli & Charcuterie
#
#    L3_Dictionary_SubCategory                  L4_dictionarySubgroup  \
# 0                        NaN                                    NaN
# 1       Beef (Bulk) - Ground        Beef Ground >10% Fat (NAMP 136)
# 2   Beef (Bulk) - Plate Cuts  Outside Skirt - Skinned (NAMP # 121E)
# 3  Beef - Deli & Charcuterie             Beef Pastrami (NAMP # 611)
# 4  Beef - Deli & Charcuterie             Beef Pastrami (NAMP # 611)
#
#                                  ProdName ItemCode                    Vendor  \
# 0    GROUND CHUCK FLAP 50% CHUCK NECK 50%      623  Golden Gate Meat Company
# 1       FINE GRIND BEEF TUBES 81/19 6/10#      624  Golden Gate Meat Company
# 2  AUST OUTSIDE SKIRT PEELED SOLD BY CASE     1717  Golden Gate Meat Company
# 3        PASTRAMI - NEW YORK STYLE- SABRA     1820  Golden Gate Meat Company
# 4      PASTRAMI SLICED 5# BAGS (50# CASE)     1821  Golden Gate Meat Company
#
#     ProdType
# 0  Canonical
# 1  Canonical
# 2  Canonical
# 3  Canonical
# 4  Canonical

# %%
df.shape
# Out:
# (1021560, 9)

# %%
# Droppig missing values
df = df.dropna(axis=0)

# Drop duplicates
df.drop_duplicates(keep='first', inplace=True)

# %% [markdown]
# # **L3 Category**

# %%
# Selecting columns for L1 category
columns = ['L2_Category', 'L3_Dictionary_SubCategory', 'ProdName']

df = df[columns]
df.head(3)
# Out:
#                      L2_Category  L3_Dictionary_SubCategory  \
# 1        Beef -- Ground & Shapes       Beef (Bulk) - Ground
# 2  Beef - Foodservice Whole Cuts   Beef (Bulk) - Plate Cuts
# 3        Beef Deli & Charcuterie  Beef - Deli & Charcuterie
#
#                                  ProdName
# 1       FINE GRIND BEEF TUBES 81/19 6/10#
# 2  AUST OUTSIDE SKIRT PEELED SOLD BY CASE
# 3        PASTRAMI - NEW YORK STYLE- SABRA

# %%
df.L3_Dictionary_SubCategory.unique()
# Out:
# array(['Beef (Bulk) - Ground', 'Beef (Bulk) - Plate Cuts',
#        'Beef - Deli & Charcuterie', 'Beef (Bulk) - Sirloin Cuts',
#        'Savory Sauces - Glace',
#        'Pork (Bulk) - Loin Cuts Incl Back Ribs & Riblets', 'Snack Kits',
#        'Pork - Sausage',
#        'Pork (Bulk) - Shoulder & Butt Incl Picnic & Brisket',
#        'Pork - Offal', 'Lamb (Bulk) - Leg', 'Lamb (Bulk) - Loin',
#        'Lamb (Bulk) - Rib Incl Racks', 'Pork - Bacon', 'Turkey - Bacon',
#        'Pork - Extremities', 'Chicken - Sausage & Bacon',
#        'Dairy --- Cheese - Natural',
#        'Turkey - Ground Incl Processed & Patty', 'Duck - Standard Cuts',
#        'Duck - Value-Added (Breaded - Cured - Etc)',
#        'Duck - Offal - Fat - Bones - Skin - Foie Gras', 'Guinea Fowl',
#        'Venison - Standard Cuts', 'Wild Boar - Standard Cuts',
#        'Shellfish - Shrimp', 'Shellfish - Lobster & Crayfish',
#        'Shellfish - Scallops & Abalone', 'Beef (Bulk) - Chuck Cuts',
#        'Beef (Bulk) - Rib Cuts',
#        'Beef (Portioned) - Chuck - Other Steaks',
#        'Admin --- Unclassifiable Products',
#        'Beef (Portioned) - Chuck - Shoulder', 'Beef (Bulk) - Brisket',
#        'Beef (Portioned) - Loin -- Tri-Tip - Ball Tip - Flap Steak',
#        'Beef (Portioned) - Loin -- Top Sirloin Butt or Cap Steak',
#        'Beef (Portioned) - Loin -- Tenderloin Steak & Tips',
#        'Beef (Bulk) - Loin Cuts',
#        'Beef (Portioned) - Loin -- Strip Loin Steak',
#        'Beef (Bulk) - Round Cuts', 'Beef (Bulk) - Foreshank & Hindshank',
#        'Offal - Extremities', 'Carcass & Bones & Skin',
#        'Beef (Portioned) - Rib -- Rib or Ribeye Steak',
#        'Beef (Portioned) - Loin -- Porterhouse & T-Bone',
#        'Beef - Ground - Patties', 'Beef (Bulk) - Trimmings & Pieces',
#        'Beef (Portioned) - Rib -- Short Ribs', 'Veal (Bulk) - Leg',
#        'Veal (Bulk) - Loin - Rack - Shoulder',
#        'Veal (Portioned) - Steaks - Chops - Cutlets',
#        'Veal (Portioned) - Osso Bucco', 'Veal - Bones & Extremities',
#        'Veal - Offal & Fat', 'Veal (Bulk) - Rib - Flank',
#        'Veal (Bulk) - Breast - Shank',
#        'Pork (Bulk) - Leg & Leg Cuts Excl Hams & Hocks',
#        'Pork (Bulk) - Belly Cuts', 'Pork (Bulk) - Tenderloin',
#        'Pork (Portioned) - Loin Chops', 'Pork (Bulk) - Ribs & Spareribs',
#        'Pork (Bulk) - Carcass & Whole',
#        'Pork (Bulk) - Ham - Special Forms',
#        'Pork (Bulk) - Hocks - Leg & Shoulder',
#        'Lamb - Carcass - Bones - Trimmings', 'Lamb (Bulk) - Shoulder',
#        'Lamb - Offal - Fat - Extremities', 'Lamb (Bulk) - Breast Cuts',
#        'Lamb (Bulk) - Fore & Hind', 'Goat - All Forms', 'Pork - Deli',
#        'Pork (Bulk) - Ham', 'Pork - Value Added - Bulk',
#        'Pork - Pancetta Bacon',
#        'Finfish Steaks & Pieces --- Salmon -- All Forms',
#        'Chicken - Whole & Half Birds',
#        'Chicken - Leg - Thigh - Drumstick',
#        'Chicken - Breast Cuts Excl Quarters', 'Cornish Hen',
#        'Turkey - Standard Cuts', 'Turkey -- Breast Cuts',
#        'Turkey - Deli Breast Incl Tavern Roasts', 'Turkey - Deli & Dog',
#        'Turkey - Offal - Fat - Skin - Bones', 'Goose', 'Pheasant',
#        'Rabbit - Hare - All Forms', 'Venison - Portioned Cuts',
#        'Wild Boar - Value Added', 'Bison - Basic Cuts',
#        'Elk - Standard Cuts', 'Elk - Value Added',
#        'Finfish Whole --- Amberjack Incl Yellowtail - Hamachi - Hiramasa - Kingfish',
#        'Finfish Whole --- Halibut',
#        'Finfish Fillets --- Salmon -- All Forms',
#        'Finfish Whole --- Salmon -- All Forms', 'Shellfish - Crab',
#        'Finfish Whole --- Snapper Incl Lane - Mangrove - Onaga - Red - Vermillion',
#        'Fat - Lard - Tallow', 'Pork - Trimmings & Stew & Kabob',
#        'Pork - Fat & Lard', 'French Fries', 'All Other Dried Meat Snacks',
#        "Apps & Hors d'Oeuvres - Americas & Europe", 'Chicken - Wing Cuts',
#        'Chicken - Offal & Fat ', 'Chicken - Deli & Dog',
#        'Chicken - Quarter Cuts', 'Chicken - Whole-Bird Cuts',
#        'Shellfish - Prawn', 'Cephalopods --- Calamari',
#        'Cephalopods --- Octopus & Cuttlefish',
#        'Finfish Fillets --- Catfish Incl Pangasius - Swai - Tra - Wolffish',
#        'Finfish Fillets --- Tilapia Incl Sheepshead',
#        'Veal - Value Added', 'Pork (Portioned) - Butt Steaks',
#        'Pork (Bulk) - Ground - Bulk',
#        'Lamb - Diced - Sliced - Ground Incl Patties',
#        'Duck - Ground - Processed - Deli', 'Beef - Franks & Sausages',
#        'Pork - Franks', 'Poultry as Main Item',
#        'Savory Sauces - Chile & Pepper', 'Turkey - Roasts',
#        'Turkey - Sausage', 'Venison - Value Added',
#        'Bison - Ground or Diced or Sliced', 'Frog',
#        'Beef (Portioned) - Plate -- Hanger or Skirt Steak', 'Suet - Fat',
#        'Beef (Portioned) - Round -- Steaks & Strips',
#        'Beef (Portioned) - Stew - Kabob - Stir Fry Pieces',
#        'Beef (Bulk) - Ground - from Primals', 'Stock Bases or Mixes',
#        'Meat As Main Item', 'Lamb - Value Added',
#        'Chicken - Breast Tenders', 'Chicken - Nuggets & Shapes',
#        'Chicken - Carcass & Extremities', 'Chicken - Skin & Bones',
#        'Chicken - Sliced - Diced - Confit',
#        'Duck - Sub-Part Pieces - Cubes - Strips  Etc',
#        'Dairy --- Eggs - Natural', 'Quail', 'Squab',
#        'Partridge & Chukhar', 'Alpaca - Camel - Kagaroo', 'Turtle',
#        'Ostrich', 'Alligator', 'Cephalopods --- Squid',
#        'Finfish Fillets --- Sole Incl Dover - Petrale - Plaice - Rex',
#        'Finfish Whole --- Opah - Opakapa - Orange Roughy',
#        'Finfish Fillets --- Trout Incl Bluegill - Rainbow - Steelhead',
#        'Finfish Steaks & Pieces --- Cod Incl Scrod & Sablefish',
#        'Finfish Fillets --- Cod Incl Scrod & Sablefish',
#        'Finfish Whole --- Cod Incl Scrod & Sablefish',
#        'Finfish Whole --- Trout Incl Bluegill - Rainbow - Steelhead',
#        'Finfish Fillets --- Snapper Incl Lane - Mangrove - Onaga - Red - Vermillion',
#        'Shellfish - Oysters', 'Finfish Fillets --- Halibut',
#        'Finfish Steaks & Pieces --- Tuna Incl Ahi - Albacore - Bluefin - Skipjack',
#        'Finfish Whole --- Tuna Incl Ahi - Albacore - Bluefin - Skipjack',
#        'Finfish Fillets --- Mackerel - Mahi Mahi - Monchong - Monkfish',
#        'Shellfish - Clams', 'Shellfish - Mussels',
#        'Finfish Whole --- Grouper',
#        'Finfish Steaks & Pieces --- Bass Incl Sea Bass - Barramundi',
#        'Finfish Loins --- Swordfish', 'Cephlapods  --- Shelf Stable',
#        'Salads -- Non - Protein Classic Forms',
#        'Chicken - Further Processed - Standard Cuts & Parts',
#        'Meat Alternatives - Ground Beef Incl Crumble & Patty', 'Burgers',
#        'Broth', 'Packing - Shipping', 'Food Wrapping Paper',
#        'Lubricants - Sealants - Other Chemicals',
#        'Admin --- Shipping & Handling Fees',
#        'Apparel & Accessories - All Other', 'Production Bags',
#        'Trash or Garbage Liners - Bags', 'Admin --- Custom Services Fees',
#        'Chicken - Ground Incl Patties - Meatballs - Gyro',
#        'Pork (Portioned) - Country Style Ribs', 'Bound Salads',
#        'Lamb - Portioned Cuts', 'Caviar', 'Pate',
#        'Mixed-Meats Products - Gyro - Shawarma - Meatloaf',
#        'Asian - All Other Asian Sauces',
#        'Turkey -- Pieces - Cubes - Strips - Etc',
#        'Pork - Value Added - Portioned',
#        'Beef - Ground - Patties - from Primals',
#        'Pork (Portioned) - Cubed Steaks',
#        'Finfish Fillets --- Skate - Smelt - Snook',
#        'Meat Alternatives - Value Added',
#        'Finfish Fillets --- Bass Incl Sea Bass - Barramundi',
#        'Pasta - Stuffed', 'Pork - Value Added Chops',
#        'Finfish Steaks & Pieces --- Trout Incl Bluegill - Rainbow - Steelhead',
#        'Finfish Fillets --- Char - Conch',
#        'Mixed-Meats Products - Specific Meats Combos',
#        'Mixed Meats - Sausage',
#        'Finfish Whole --- Paiche - Paddlefish - Parrot - Pike',
#        'Salt - All Forms', 'Admin --- Samples & Sales Services',
#        'Soup Bases or Mixes', 'Soups',
#        'Finfish Whole --- Tilapia Incl Sheepshead', 'Imitation Seafoods',
#        'BevAlc - Cocktails RTD', 'BevAlc - Wine - White',
#        'BevAlc - Cordials & Liqeuers', 'BevAlc - Brandy & Cognacs',
#        'BevAlc - Gin', 'BevAlc - Rum & Cachaca', 'BevAlc - Whiskeys',
#        'BevAlc - Wine - Red', 'BevAlc - Wine - Fortified',
#        'BevAlc - Vodka Incl Flavored',
#        'BevAlc - Sparkling Wines - Champagne - Prosecco',
#        'BevAlc - Beer - Ales & Stouts', 'NA-Beverage - Cocktail Mixes',
#        'Drinkware - Wine & Champagne Glasses',
#        'BevAlc - Tequila & Mezcal',
#        'NA-Beverage - Sodas CSDs - All Other Flavored Incl Variety',
#        'BevAlc - Wine - Rose', 'BevAlc - Aperitifs & Digestifs',
#        'NA-Beverage - Coffee -- Ground - Bag or Bulk',
#        'Bar Service Supplies Excl Wares',
#        'Drinkware - Cocktail Glassware',
#        'NA-Beverage - Flavorings & Flavoring Syrups',
#        'Filters - Coffee & Tea - Disposable',
#        'NA-Beverage - Water - Sparkling',
#        'BevAlc - Beer - Lagers & Pilsners', 'BevAlc - Sake & Plum Wine',
#        'Fruit -- Pureed - Shelf-Stable - Chilled - Frozen',
#        'Drinkware - Water Glasses & Goblets', 'Cooking Wines & Related',
#        'BevAlc - Lambics & Meads & Malts', 'NA-Beverage - Water - Still',
#        'BevAlc - All Other Spirits', 'Cleaners --- Equipment Specific',
#        'BevAlc - Wine - Dessert or Icewine', 'Pickles',
#        'Fruit or Flowers or Nuts - Pickled or Preserved',
#        'Vegetables - Pickled or Preserved', 'Olives and Capers',
#        'NA-Beverage - Tea -- Bags', 'NA-Beverage - Tea -- Leaf Bulk',
#        'NA-Beverage - Sodas CSDs - Seltzer and Club Not Flavored',
#        'Drinkware - All Other Glassware',
#        'NA-Beverage - Sodas CSDs - Tonic & Ginger',
#        'NA-Beverage - Juices & Drinks -- Apple Incl Cider',
#        'Textile Towels - Cloths - Rags',
#        'NA-Beverage - Bitters & Tinctures & Shrubs',
#        'NA-Beverage - Energy & Alertness',
#        'Floorstanding -- Refrigerators & Freezers',
#        'Sugar - Excl Substitutes', 'Sugar Substitutes',
#        'NA-Beverage - Sodas CSDs - Root & Birch Beers',
#        'Countertop -- Refrigerators & Freezers',
#        'Countertop -- Bar & Beverage', 'BevAlc - Wine - All Other',
#        'Oil - Olive', 'Drinkware - Cups - Saucers - Mugs',
#        'Liquid Sweetener - All Other', 'Extracts & Flavorings',
#        'Dining Room Supplies Excl Wares',
#        'Drinkware - Beer Glasses Incl Pint & Mixer',
#        'Dairy --- Dairy Beverages',
#        'NA-Beverage - Coffee -- Portioned - Pods & FracPaks',
#        'Serving Cups & Lids - Cold Drink', 'Service Cups - Accessories',
#        'Serving Cups & Lids - Hot Drink', 'BevAlc - Hard Sodas',
#        'Candy - Primarily Chocolate Excl Chocolate Bars',
#        'Takeout & Delivery Supplies',
#        'NA-Beverage - Thickeners - CO2 - Rimmers - Supplements',
#        'NA-Beverage - Juices & Drinks -- Ades e.g. Lemonade',
#        'BevAlc - Hard Cider', 'NA-Beverage - Tea -- RTD',
#        'NA-Beverage - Juices & Drinks -- Clam & Clamato',
#        'Serving Cups & Lids - General Use', 'Flatware - Spoons',
#        'Savory Sauces - Red Sauces', 'NA-Beverage - Coffee -- Whole Bean',
#        'Beverage - Hemp and CBD ',
#        'Fruit -- All Other - Fresh Whole or Cut',
#        'Biscuits - Bagels - Breadsticks - Etc',
#        'Pancakes - Wafles - French Toast - Crepes & Blinis',
#        'Breads - Rolls - Buns - Etc', 'Muffins - Scones - Donuts - Etc',
#        'Pastries', 'Spices - Dried Herbs', 'Breadsticks & Bread Crisps',
#        'Dough', 'Brownies - Squares - Etc', 'Nutrition Bars',
#        'Cakes - Cupcakes - Etc', 'Bakery - Add-Ins',
#        'NA-Beverage - Cocoa', 'Mousse - Parfait - Souffle', 'Cookies',
#        'NA-Beverage - Coffee -- Instant - Concentrates - Bases',
#        'Candy - Gummy Incl Licorice',
#        'Dairy --- Cheese - Cultured Products',
#        'NA-Beverage - Tea -- Pods - FracPaks - Etc',
#        'NA-Beverage - Tea -- Instant - Concentrates - Bases',
#        'American - Steak Sauces', 'Chutneys',
#        'American - All Other Sauces', 'Latin American - Hot Sauces',
#        'American - Hot Sauces', 'Savory Sauces - Wing Sauce', 'Mustard',
#        'Savory Sauces - All Other', 'Asian - Soy Sauces',
#        'NA-Beverage - Juices & Drinks -- Fruit - Citrus',
#        'Dough Shell or Crust', 'Wraps & Skins', 'Crackers',
#        'Savory Pastes', 'Asian - Hot Sauces', 'Batter - RTU',
#        'Sweet Crackers & Crumbs', 'Pies - Cobblers - Etc',
#        'Crackers - Assortments',
#        'Breading and Breaders and Crouton - RTU',
#        'Prepared - Snack - Chips Etc - RTC - RTS - RTE --- Crackers & Breadsticks',
#        'Shells RTU', 'Dairy --- Milk -- from Animals',
#        'Dairy --- Cream Including Alternatives', 'Dairy --- Buttermilk',
#        'Dairy --- Milk -- from Plants', 'Dairy --- Creamers -- All Forms',
#        'Dairy --- Yogurt', 'Ice Cream', 'Sherbert & Sorbet',
#        'Frozen Novelties Incl Ices', 'Frozen Yogurt',
#        'Non-Dairy Ice Cream Alternatives', 'Frozen Custard & Soft Serve',
#        'Salad Dressing RTU - Bulk', 'Salad Dressing Mix',
#        'Salad Dressing RTU - Tabletop', 'Mayonnaise - Bulk',
#        'Mayonnaise - Tabletop', 'American - Tartar Sauces',
#        'Dips - All Hummus', 'Dips - All Other',
#        'Fruit -- Avocado - Fresh Whole or Cut',
#        "Apps & Hors d'Oeuvres - Pan-Asian", 'Hot Dogs - Franks',
#        'Pasta Dishes', 'Noodle Dishes', 'Potato Dishes',
#        'Asian Dishes Excluding Rice & Noodle Dishes', 'Pasta - Simple',
#        'Mexican Dishes', 'Tortillas', 'Sandwiches - Mexican',
#        'Pizzas - Flatbread - Calzone - Stromboli',
#        'Sweet Sauces - RTU & Bases or Mixes',
#        'Tomato - Fresh Whole or Cut',
#        'Fruit -- Apples - Fresh Whole or Cut',
#        'Finfish Shelf Stable --- All Others', 'Peas - Fresh Whole',
#        'Beans (Not Legumes) - Frozen', 'All Other - Shelf Stable',
#        'Beets - Fresh Whole or Cut', 'All Other Salty Snacks',
#        'Garlic or Ginger Processed', 'Noodles', 'Nuts - Dried',
#        'Fruit -- All Other - Shelf Stable',
#        'Cabbage - Fresh Whole or Cut', 'Asian Hoisin Sauce',
#        'Sweet Pastes', 'Carrot - Fresh Whole or Cut',
#        'Fruit -- Melon - Fresh Whole or Cut', 'Oil - Other Plant Based',
#        'Molasses', 'Mushrooms - Dried', 'Mushrooms - Shelf Stable',
#        'Truffles - Fresh', 'Spices', 'Celery - Fresh Whole or Cut',
#        'Tomato - Shelf Stable', 'Fresh Herbs',
#        'Corn - Fresh Whole or Cut', 'Bakery - Decorative & Enrobing',
#        'Chocolate Bars - All Types', 'Cucumber - Fresh Whole or Cut',
#        'All Other - Fresh Whole or Cut', 'Bakery - Crumbs or Grind',
#        'Radish - Fresh Whole or Cut',
#        'Baking Soda - Baking Powder - Yeast',
#        'Eggplant - Fresh Whole or Cut',
#        'Fruit -- Citrus - Fresh Whole or Cut', 'Gelatin & Aspic',
#        'Preservatives', 'Additives',
#        'Non-Fountain Syrups Incl Maple Syrups',
#        'Leafy Greens -- Primarily Salad', 'Sweet Glaze or Icing - RTU',
#        'Batter - Bases & Mixes & Finishing', 'Bakery - Bases & Mixes',
#        'Seasonings', 'Onion & Shallot - Fresh Whole or Cut',
#        'Food Coloring', 'Fruit -- Citrus - Shelf Stable',
#        'Mushrooms - Fresh', 'Fruit -- Pears - Fresh Whole or Cut',
#        'Peppers - Fresh Whole or Cut',
#        'Chili Peppers - Fresh Whole or Cut', 'Flour - All Forms',
#        'Dessert Topping - RTU',
#        'NA-Beverage - Juices & Drinks -- Fruit - Berry',
#        'Fruit -- Cherries - Frozen', 'Fruit -- Citrus - Frozen',
#        'Potato - Fresh Whole or Cut', 'Cones',
#        'Dispensers of Food & Beverage Ingredients', 'NA-Beverage - Sport',
#        'NA-Beverage - Sodas CSDs - Colas',
#        'NA-Beverage - Sodas CSDs - Dr Pepper',
#        'NA-Beverage - Iced Tea - Dispensed / Syrup',
#        'Fruit -- Apples - Shelf Stable', 'Fruit Snacks', 'Fruit - Dried',
#        'Sweet Potato - Fresh Whole or Cut',
#        'Fruit -- Cherries - Shelf Stable',
#        'Breading and Breaders and Crouton - Bases & Mixes',
#        'Fruit -- Mixed or Assorted - Shelf Stable',
#        'Fruit -- Berries - Fresh Whole or Cut',
#        'Fruit -- Pears - Shelf Stable', 'Sweet Fillings RTU',
#        'NA-Beverage - Juices & Drinks -- Fruit - All Other', 'Salsa',
#        'Squash - Fresh Whole or Cut', 'Fruit -- Apples - Frozen',
#        'Fruit -- Banana - Fresh Whole or Cut',
#        'Fruit -- Berries - Frozen', 'Fruit -- Banana - Frozen',
#        'Zucchini - Fresh Whole or Cut', 'Fruit -- All Other - Frozen',
#        'Rhubarb - Frozen',
#        'Vegetables - Mixed or Assorted - Fresh Whole or Cut',
#        'Cauliflower - Fresh Whole or Cut', 'Broccoli - Frozen',
#        'Broccoli - Fresh Whole or Cut', 'Dessert - Bases & Mixes',
#        'Gelatins', 'Puddings', 'Vegetable Snacks',
#        'Pumpkin - Fresh Whole or Cut',
#        'Fruit -- Mixed or Assorted - Fresh Whole or Cut',
#        'Antipasto - Bruschetta - Charcuterie - Etc', 'Bean Dishes',
#        'Beans & Legumes - Can or Jar', 'Beans & Legumes - Frozen',
#        'Bread and Tortilla - Bases & Mixes', 'Savory Fillings',
#        'Breakfast Mixed Mains', 'Ketchup',
#        'Spices - Dried Ground Chili Peppers',
#        'Salad Dressing RTU - Portion Control', 'Honey', 'Preserves',
#        'Jams', 'Marmalade', 'Jelly',
#        'Jam - Jelly - Preserves Assortments', 'Dairy --- Butter',
#        'Mayonnaise - Portion Control', 'Fruit or Nut Spreads & Butters',
#        'Pepper - All Forms', 'Relish', 'Savory Sauces - BBQ',
#        'Hot Cereal', 'Vinegar - All Other',
#        'NA-Beverage - Water - Coconut',
#        'NA-Beverage - Juices & Drinks -- Mixed Flavors',
#        'NA-Beverage - Coffee -- RTD',
#        'NA-Beverage - Juices & Drinks -- Vegetable',
#        'NA-Beverage - Fermented', 'NA-Beverage - Sodas CSDs - Cream',
#        'Fruit -- Cherries - Fresh Whole or Cut',
#        'Beef (Portioned) - Cubed & Braising Steak',
#        'Pork - Canadian Bacon', 'Turkey - Ham',
#        'NA-Beverage - Smoothies & Shakes',
#        'NA-Beverage - Clinical & Nutritional Beverages', 'Thickeners',
#        'Trail Mix', 'Candy - All Other Forms Excl Chocolate',
#        'Candy - Marshmallow', 'Candy - Hard Incl Lollipops',
#        'NA-Beverage - Water', 'Straws', 'Egg Dishes',
#        'Dairy --- Eggs - Processed',
#        'Garlic - Fresh - Frozen - Chilled - Shelf Stable',
#        'Skewers - Etc', 'Seafood as Main Item', 'Rice Dishes',
#        'Bowls & Food Cups Incl Lids', 'Pretzels - Unflavored',
#        'Meal - Cornmeal - Polenta', 'Seeds', 'Oil - Blends',
#        'Oil - Canola', 'Oil - Olive Oil - Flavored', 'Oil - Truffle',
#        'Oil - Nut & Seed Based', 'Oil - Fruit & Flower Based',
#        'Oil - Specialty Food-Specific', 'Couscous - Quinoa - Wheats Etc',
#        'Gravy and Au Jus - Bases & Mixes', 'Rice',
#        'All Other Nutrition Snacks', 'Gravy and Au Jus - RTU',
#        'Dips - Mexican - Incl Queso and Nacho',
#        'Ladles - Spoons - Scoops', 'Bouillon',
#        'Finfish Shelf Stable ---Tuna', 'Shellfish Battered or Breaded',
#        'Mixed-Seafoods Products', 'Finfish Battered or Breaded',
#        'Finfish Loins --- Cod Incl Scrod & Sablefish',
#        'Finfish Fillets --- Haddock  & Hake',
#        'Finfish Fillets --- Pollock',
#        'Finfish Steaks & Pieces --- Swordfish',
#        'Finfish Loins --- Tuna Incl Ahi - Albacore - Bluefin - Skipjack',
#        'Shortening', 'Liquid Frying & Pan Oils',
#        'Liquid Butter Alternatives', 'All Other Chips',
#        'Nuts - Snack Bar', 'Popcorn Incl Flavored',
#        'Potato Chips - Alternative', 'Potato Chips - Unflavored',
#        'Potato Chips - Flavored',
#        'Potato Chips - Assorted or Variety Packs', 'Tortilla Chips',
#        'Stews', 'Cleaners --- Surface Specific',
#        'Table & Counter Dispensers & Shakers', 'Spice Blends',
#        'Water Treatment Chemicals',
#        'Asian Vegetables - Pickled or Preserved', 'Bakery Tools', 'Asian',
#        'Chili Peppers - Dried Whole', 'All Other Kitchen Smallwares',
#        'Marinades', 'Vinegar - Balsamic', 'Vinegar - Wine Based',
#        'Vinegar - Fruit Based', 'Vinegar - Plain White or Black',
#        'Artichoke - Shelf Stable', 'Beans (Not Legumes) - Shelf Stable',
#        'Beet - Shelf Stable', 'Corn - Shelf Stable',
#        'Peppers - Shelf Stable', 'Fermented Vegetables',
#        'Vegetables - Mixed or Assorted - Frozen or Refr',
#        'All Other - Frozen or Refr', 'Carrot - Frozen',
#        'Cauliflower - Frozen', 'Corn - Frozen', 'Onion Rings',
#        'Peas - Frozen', 'Yam & Sweet Potato Items', 'Potato - Frozen',
#        'Leafy Greens - Frozen', 'Fruit -- Grapes - Fresh Whole or Cut',
#        'Sprout and Shoot - Fresh Whole', 'Slicers & Cutting Machines',
#        'Leek & Scallion - Fresh Whole or Cut',
#        'Asparagus - Fresh Whole or Cut', 'Micro Greens',
#        'Turnip - Fresh Whole or Cut', 'Flowers - Display',
#        'Rhubarb - Fresh Whole or Cut', 'Plants - Display or Edible',
#        'Beans (Not Legumes) - Fresh Whole',
#        'Leafy Greens -- Citrus & Special Edible Leaves',
#        'Artichoke - Fresh Whole', 'Herbs - Micro', 'Micro Lettuce',
#        'Micro Vegetables', 'Flowers - Edible', 'Yam - Fresh Whole or Cut',
#        'Pans Incl Pan Lids', 'Lids Only for Containers',
#        'Tray Accessories', 'Food Wrap & Sheets', 'Production Cups & Lids',
#        'General Use Containers - Separate Lids',
#        'General Use Carriers & Trays & Parts',
#        'General Use Containers - Hinged Box',
#        'Shape Specific Containers for Service', 'Pots - Pans & Related',
#        'Chefs Wear', 'Gloves - Mitts - Pads', 'Health Supplies',
#        'Item Specific Bags', 'General Use Bags', 'Painting & Coloring',
#        'Bain Marie - Steam Table - Steamers', 'Paper - Pads - Notebooks',
#        'Packaging Boards',
#        'Production Storage Containers - Lids - Liners',
#        'Savory Filling Mixes', 'Item Specific Containers for Service',
#        'Plates & Plate Lids', 'General Use Containers - Hinged Clamshell',
#        'Trays', 'Item Specific Containers for Production',
#        'Candles & Lamps', 'Janitorial --- Toilet & Urinal',
#        'Janitorial --- Brooms & Dust Pans', 'Scrub - Brush - Sponge',
#        'Janitorial --- Brushes & Squeegees',
#        'Mop & Bucket Parts & Accessories Excl Heads',
#        'Grill - Griddle - Oven', 'Mops Only',
#        'Waste Containers & Lids - All Types',
#        'Waste Management Accessories',
#        'Janitorial --- Buckets & Caddies Excl Mop', 'Mop & Bucket Combos',
#        'Production-Area Signs', 'Mop Heads Only', 'Mops - Wet',
#        'Mop & Bucket Parts & Accessories',
#        'Containers for Production - All Shapes & Types',
#        'Serving Cups & Lids - Food',
#        'Dispensers --- Soap - Cleaners - Air Freshener',
#        'Dairy --- Margarine', 'Service Cutlery Incl Chopsticks',
#        'Sticks - Picks - Skewers', 'Tongs - Turners - Spatulas',
#        'Cutting Wares', 'Promo & Party',
#        'Non-Disposable Tablecloths - Skirts - Placemats',
#        'Tofu and Tempeh and Seitan',
#        'Dispensers - Napkins & Facial Tissues', 'Dispensers - Towels',
#        'Janitorial --- Sprayers', 'Dispensers - All Toilet Related',
#        'Netting - Cloths - Twine', 'Paper Napkins & Related',
#        'Facial Tissues', 'Textile Napkins & Accessories',
#        'Paper Placemats & Table Coverings', 'Lamb (Bulk) - Other Cuts',
#        'Chafing (Gel) Fuel & Cannisters', 'Butane & Propane Fuel',
#        'Food Warming & Melting', 'Charcoal & Wood Incl Starters',
#        'Food Labels Incl Rotation', 'Binder & Clipboard',
#        'Cabinets & Shelving', 'Cash & Check Handling',
#        'Guest Checks - Presenters - Pads', 'POS & Cash Register',
#        'Lighting & Heating - Cooling',
#        'Cold Cereal [BREAK THIS L3 DOWN FURTHER]',
#        'Production Equipment Filters', 'Water Filters',
#        'Toilet Paper - Tissue', 'Grain Dishes', 'Disposable Wipes',
#        'Degreaser', 'Paper Towels', 'Trays - Traystands - Service Carts',
#        'Multi-Compartment Food Containers - Trays - Lids',
#        'Item Specific Carriers & Trays', 'Tape & Fasten',
#        'Tableware - Plates & Accessories', 'Tableware - Serving Platters',
#        'Tableware - Bowls - Dishes & Accessories',
#        'Tableware - All Other', 'Bar Tools', 'Floor Mats',
#        'Finfish Fillets --- Butterfish - Cobia - Escolar - Lionfish',
#        'Dairy --- Cheese - Processed', 'Guest Amenities',
#        'Buffet Supplies Excl Wares', 'Item Specific Dispensers',
#        'Food Production Small Tools & Appliances', 'Carts',
#        'Finfish Fillets --- Sable - Scad - Shad - Shark',
#        'Production Tables', 'Timers & Thermometers',
#        'Butane & Propane Lighters',
#        'Flatware - All Other Incl Holders & Accessories', 'Tools',
#        'Production Dish & Warewashing', 'HVAC', 'Warewashing Racks',
#        'Measures & Scales Incl Dishers', 'First Aid', 'Flatware - Forks',
#        'Flatware - Knives',
#        'Countertop -- Food Processors, Blenders & Mixers',
#        'Floorstanding -- Fryolators - Fryers - Poppers', 'Workstations',
#        'Service Furnishings',
#        'Finfish Whole --- Bass Incl Sea Bass - Barramundi',
#        'Seashells - Barnacle - Cockle - Conch - Urchin', 'Pizza Wares',
#        'Plumbing Fixtures & Parts', 'Detergent --- Presoak', 'Ovenwares',
#        'Countertop -- Broilers & Ovens & Stoves & Toasters',
#        'Finfish Fillets --- Amberjack Incl Yellowtail - Hamachi - Hiramasa - Kingfish',
#        'Rinse - Warewashing', 'Detergent --- Machine Warewashing',
#        'Sanitizer --- Dish', 'All Purpose Cleaners', 'Disinfectant',
#        'Bleach', 'Polishes & Protectants', 'Cleaners - Bathroom Specific',
#        'Pest Control', 'Sanitizer', 'Detergent',
#        'Detergent --- Pot & Pan', 'Safety and Security Supplies',
#        'Air Fresheners', 'Hand Soaps & Sanitizers',
#        'Soap --- Dish Excl Machine', 'Descaler & Delimer',
#        'Stain Remover --- Dish',
#        'Finfish Steaks & Pieces --- Carcass & Meat',
#        'Finfish Fillets --- Paiche - Paddlefish - Parrot - Pike',
#        'Vegetable Dishes', 'Snack Mix', 'Finfish Whole - Anchovy', 'Roe',
#        'Shellfish --- Shelf Stable', 'Artichoke - Frozen',
#        'Onion & Shallot - Frozen', 'Asparagus - Frozen',
#        'Tomato - Frozen or Refrigerated Incl Cut',
#        'Fritters - Croquetttes - Fried Balls - Felafel',
#        'Meal Kits & Portioned Meals', 'Gift Baskets or Boxes',
#        'Sea - Fresh Whole', 'Fruit -- Avocado - Frozen or Refr',
#        'Chili Peppers - Frozen', 'Candy', 'Salad Kits',
#        'Beef (Bulk) - Sides & Quarters', 'Bison - Value Added',
#        'Bison - Bones & Offal & Trimmings', 'Antelope',
#        'Finfish Fillets --- Flounder Incl Dab & Fluke & Turbot',
#        'Sandwiches - Deli', 'Snacks - Pre-Dipped or with Dip',
#        'Vegetables - Mixed or Assorted - Shelf Stable',
#        'Asparagus - Shelf Stable', 'Potato - Shelf Stable',
#        'Carrot - Shelf Stable', 'Dried Vegetables', 'Dysphagia Foods',
#        'Granola - Yogurt Parfaits Etc',
#        'Fruit -- Mixed or Assorted - Frozen', 'Beans & Legumes - Dried',
#        'Eggplant - Shelf Stable', 'Fruit -- Melon - Shelf Stable',
#        'Fruit --Banana - Shelf Stable', 'Peas - Shelf Stable', 'Spread',
#        'Fruit -- Melon - Frozen',
#        'Potato and - or Onion Dishes Incl French Fries', 'Onion Dishes',
#        'Casseroles - Cassoulets - Gratins - Etc',
#        'All Other Energy Snacks', 'Nouveau Condiments', 'Condiment Kits',
#        'Finfish Loins --- Catfish Incl Pangasius - Swai - Tra - Wolffish',
#        'Finfish Whole --- Haddock  & Hake', 'Jerky',
#        'Sandwiches - Stacked', 'Finfish Loins --- Pollock',
#        'Finfish Whole --- Catfish Incl Pangasius - Swai - Tra - Wolffish',
#        'Finfish Steaks & Pieces --- Halibut',
#        'Finfish Fillets --- Grouper',
#        'Finfish Fillets --- Tuna Incl Ahi - Albacore - Bluefin - Skipjack',
#        'Sandwiches - Greek',
#        'Finfish Steaks & Pieces --- Catfish Incl Pangasius - Swai - Tra - Wolffish',
#        'Finfish Loins --- Haddock  & Hake', 'Pork (Bulk) - Ham - Steaks',
#        'Countertop -- Concessions Equipment',
#        'Finfish Fillets --- Opah - Opakapa - Orange Roughy',
#        'Finfish Steaks & Pieces --- Dorade - Dory - Drum',
#        'Pork (Bulk) - Ground - Patties',
#        'Finfish Steaks & Pieces --- Pollock',
#        'Finfish Loins --- Salmon -- All Forms', 'Sausages',
#        'Finfish Steaks & Pieces --- Flounder Incl Dab & Fluke & Turbot',
#        'Finfish Fillets --- Dorade - Dory - Drum',
#        'Finfish Steaks & Pieces --- Amberjack Incl Yellowtail - Hamachi - Hiramasa - Kingfish',
#        'Finfish Steaks & Pieces --- Grouper', 'Pet Foods & Treats',
#        'Custards & Brulees', 'Bakery - Wraps', 'Pretzels - Flavored',
#        'Sandwiches - Breakfast', 'Chili Bases or Mixes',
#        'Latin American - Taco Sauces',
#        'Indian Dishes Excluding Stews - Biryani - Breads',
#        'Sushi - SE Asian', 'Consomme', 'Asian - BBQ Sauces', 'Gelato',
#        'Sandwiches - PBJ - Peanut Butter & Jelly or Similar',
#        'Stew Bases or Mixes', 'Display Cases', 'Asian - Duck Sauce',
#        'Tapenade', 'Mailing', 'Mop Buckets Only', 'Baby Foods',
#        'Fabric Treatment', 'Energy Bars', 'OTC Drugstore Products',
#        'Floorstanding -- Grill & Griddle', 'Plants - Display',
#        'Ladder - Pallet - Truck - Dolly', 'Nut Snacks', 'Malt -  Germ',
#        'Kiddie Activities', 'Racks', 'Janitorial --- Equipment Pads',
#        'Wrap Dispensers', 'Countertop -- Grill & Griddle',
#        'Janitorial - Ice Melt', 'Office Accessories',
#        'Lids - Non-Disposable', 'Specialty Food Containers - Trays',
#        'Dispensers - Cup - Lid - Carriers',
#        'Floorstanding -- Ice Bins & Machines',
#        'Menu Books - Boards & Related', 'Liners & Tissues',
#        'Facility & Room Accessories', 'Air Filters', 'Bags & Hampers',
#        'Writing & Drawing', 'Coasters', 'Customer Signage',
#        'Sanitizer - Sour - Stain', 'Electronics and Accessories',
#        'Laminating and Covering', 'Janitorial --- Cleaning Appliances',
#        'Production Equipment Parts',
#        'Countertop -- Broilers & Ovens & Stoves', 'Sanitary Napkins',
#        'Specialty Dispensers & Dispenser Accessories',
#        'Countertop -- Fryolators - Fryers - Poppers',
#        'Specialty Waste Liners - Bags', 'Ice All Forms',
#        'Wall Accessories', 'Floorstanding -- Food Processors & Mixers',
#        'Janitorial --- Spill & Hazard', 'Service Fixtures', 'Batteries',
#        'Healthcare Facilities Supplies', 'Snake',
#        'Finfish Fillets --- Wahoo - Whiting',
#        'Finfish Loins --- Wahoo - Whiting',
#        'Finfish Fillets --- Barracuda - Blackfish - Bluefish - Bluenose',
#        'Japanese Dishes',
#        'Finfish Whole --- Scup - Sculp - Sculpin - Sea Bream - Porgie',
#        'Wild Boar - Portioned Cuts',
#        'Finfish Whole --- Sole Incl Dover - Petrale - Plaice - Rex',
#        'Finfish Whole --- Mackerel - Mahi Mahi - Monchong - Monkfish',
#        'Finfish Loins --- Amberjack Incl Yellowtail - Hamachi - Hiramasa - Kingfish',
#        'Finfish Whole --- Eel Incl Unagi',
#        'Finfish Whole --- Flounder Incl Dab & Fluke & Turbot',
#        'Finfish Whole --- Marlin - Milkfish - Morwong - Mullet',
#        'Finfish Whole --- Skate - Smelt - Snook',
#        'Finfish Whole  --- Char - Conch',
#        'Finfish Whole --- Perch - Pike - Pompano', 'Admin --- Credits',
#        'Finfish Steaks & Pieces --- Mackerel - Mahi Mahi - Monchong - Monkfish',
#        'Finfish Whole --- Dorade - Dory - Drum',
#        'Finfish Whole --- Butterfish - Cobia - Escolar - Lionfish',
#        'Finfish Fillets --- Scup - Sculp - Sculpin - Sea Bream - Porgie',
#        'Finfish Whole --- Barracuda - Blackfish - Bluefish - Bluenose',
#        'Finfish Whole --- Wahoo - Whiting',
#        'Finfish Steaks & Pieces --- Butterfish - Cobia - Escolar - Lionfish',
#        'Label and Sticker', 'Strippers', 'Baby Changing',
#        'Finfish Steaks & Pieces --- Wahoo - Whiting',
#        'Finfish Whole --- Swordfish',
#        'Admin --- Finance & Transaction Fees',
#        'Fruit - Berries - Shelf Stable',
#        'NA-Beverage - Juices & Drinks -- All Other', 'Ink and Cartridges',
#        'Brines', 'Finfish Fillets --- Swordfish',
#        'Medical Equipment & Instruments', 'Lawn Management',
#        'Folders - Folios', 'Janitorial --- Grab - Reach - Pick',
#        'Desk Organizing', 'Detergent --- Glassware', 'Mousse',
#        'Calendar & Planner', 'Cutting', 'Presentation Items',
#        'Event and Identification Management', 'Security Tools & Supplies',
#        'Toner Cartridges', 'Specialized Stain Removers',
#        'Finfish Loins --- Halibut', 'Sandwiches - Meat Incl BBQ',
#        'Tents - Tarps - Table Umbrellas Etc',
#        'Finfish Fillets --- Tilefish - Trigger Fish', 'Zucchini - Frozen',
#        'Squash - Frozen',
#        'Finfish Loins --- Flounder Incl Dab & Fluke & Turbot',
#        'Beans & Legumes - Fresh Incl Refrigerated',
#        'Truffles - Shelf Stable', 'Molds & Mold Liners',
#        'Finfish Whole --- Carp - Chub - Crappie - Croaker - Cusk',
#        'Mushrooms - Frozen', 'Finfish Fillets --- Perch - Pike - Pompano',
#        'Finfish Loins --- Opah - Opakapa - Orange Roughy',
#        'Finfish Loins --- Mackerel - Mahi Mahi - Monchong - Monkfish',
#        'Admin --- Returns', 'Food Washes', 'Eggplant - Frozen',
#        'Sandwiches - Italian', 'Savory Sauces - Gift Box',
#        'NA-Beverage - Water - Specialty', 'Salads -- Protein Centric',
#        'Floorstanding -- Broilers & Ovens & Stoves',
#        'Finfish Loins --- Bass Incl Sea Bass - Barramundi',
#        'Walk-In Freezers - Refrigerators - Combos',
#        'Finfish Loins --- Sable - Scad - Shad - Shark',
#        'Finfish Fillets --- Anchovy',
#        'Finfish Fillets --- Eel Incl Unagi',
#        'Finfish Steaks & Pieces --- Haddock  & Hake',
#        'Cucumber - Shelf Stable',
#        'Finfish Whole --- Tilefish - Trigger Fish',
#        'Finfish Loins --- Marlin - Milkfish - Mullet', 'Plants - Edible',
#        'Finfish Whole --- Sardines',
#        'Finfish Whole --- Sable - Scad - Shad - Shark',
#        'Sandwiches - Reibens & Rachels',
#        'Finfish Fillets --- Herring - Hogfish - Kipper',
#        'Other Fuels & Heat Packs', 'Books - All Types',
#        'Finfish Whole --- Herring - Hogfish - Kipper',
#        'Finfish Whole --- Pollock', 'Dairy --- Desserts & Toppings',
#        'Zucchini - Shelf Stable', 'Finfish Fillets --- Barrelfish ',
#        'Finfish Loins --- Butterfish - Cobia - Escolar - Lionfish',
#        'Finfish Steaks & Pieces --- Sable - Scad - Shad - Shark',
#        'Finfish --- Mackerel - Mahi Mahi - Monchong - Monkfish',
#        'Peppers - Frozen',
#        'Finfish Steaks & Pieces --- Perch - Pike - Pompano',
#        'Finfish Loins --- Tilapia Incl Sheepshead',
#        'Sweet Potato - Shelf Stable', 'Printers',
#        'Finfish --- Salmon -- All Forms',
#        'Finfish Steaks & Pieces --- Snapper Incl Lane - Mangrove - Onaga - Red - Vermillion',
#        'Frozen Herbs',
#        'Finfish Steaks & Pieces --- Paiche - Paddlefish - Parrot - Pike',
#        'Finfish Steaks & Pieces --- Char - Conch',
#        'Finfish Steaks & Pieces --- Skate - Smelt - Snook',
#        'Finfish Steaks & Pieces --- Opah - Opakapa - Orange Roughy',
#        'Finfish Loins --- Paiche - Paddlefish - Parrot - Pike',
#        'Finfish Steaks & Pieces --- Barracuda - Blackfish - Bluefish - Bluenose',
#        'Finfish Fillets --- Marlin - Milkfish - Mullet'], dtype=object)

# %%
# Counting L2 Category classes
len(df.L3_Dictionary_SubCategory.unique())
# Out:
# 984

# %%
# Importing Libraries
# import nltk
# from nltk.corpus import stopwords

# # Download stopwords
# nltk.download("stopwords")

# %%
# Preprocessing fuction for category
def class_pre(text):
  new_text = re.sub(r'&', 'and', text)
  new_text = re.sub(r'[^\w\s]',' ', new_text)
  new_text = re.sub(r' +', ' ', new_text)
  new_text = re.sub(r'\s', '_', new_text)
  return new_text

# %%
# Did a slight modification, convert & into and
# Then removes extra whitespaces

# def clean(string):
#     string = re.sub('&', 'and ', string)
#     raw_text = re.sub("[^a-zA-Z]+", " ", string)
#     raw_text = re.sub(' +', ' ', raw_text)
#     raw_text = raw_text.strip()
#     words = raw_text.lower().split()
#     stops = set(stopwords.words("english"))
#     meaningful_words = [
#         word for word in words if ((not word in stops) and (len(word) >= 3))
#     ]
#     string = " ".join(meaningful_words)
#     return string

# %%
# uniques = df.L2_Category.unique()

# for word in uniques:
#   pp = class_pre(word)
#   print(pp)

# %%
# making the category
df['L3'] = df['L3_Dictionary_SubCategory'].apply(class_pre)

# %%
# Creating label of the class according to the fasttext format
df['category'] = '__label__' + df['L3'].astype(str)

# %%
# Drop used columns
df = df.drop(['L3_Dictionary_SubCategory', 'L3'], axis=1)

# %%
# Creating catehory description with producbt name and vendor
df['category_description'] = df['category'] + ' ' + df['L2_Category'] + ' ' + df['ProdName']
# df['category_description'] = df['L0_Category'] + ' ' + df['L1_Class'] + ' ' + df['ProdName']

# %%
#  Drop the columns : ProdName, L0_Category, L1_Class
df = df.drop(['L2_Category', 'ProdName'], axis=1)

# %%
df.head()
# Out:
#                              category  \
# 1           __label__Beef_Bulk_Ground
# 2       __label__Beef_Bulk_Plate_Cuts
# 3  __label__Beef_Deli_and_Charcuterie
# 4  __label__Beef_Deli_and_Charcuterie
# 5  __label__Beef_Deli_and_Charcuterie
#
#                                 category_description
# 1  __label__Beef_Bulk_Ground Beef -- Ground & Sha...
# 2  __label__Beef_Bulk_Plate_Cuts Beef - Foodservi...
# 3  __label__Beef_Deli_and_Charcuterie Beef Deli &...
# 4  __label__Beef_Deli_and_Charcuterie Beef Deli &...
# 5  __label__Beef_Deli_and_Charcuterie Beef Deli &...

# %%
# Replace all white spaces whith single space
# Remove white spaces in begining and end of the text
# Turn text into lower case

# Preprocessing Function
def preprocess(text):
    text = re.sub(r'&', 'and', text)
    text = re.sub(r'[^\w\s]',' ', text)
    text = re.sub(' +', ' ', text)
    return text.strip().lower()

# %%
# Apply preprocessing function to 'category_description'

df['category_description'] = df['category_description'].apply(preprocess)
# df['category_description'] = df['category'].apply(preprocess) + ' ' + df['category_description'].apply(clean)

# %%
# Test Train splitting
from sklearn.model_selection import train_test_split

# 98% training | 2% testing
train, test = train_test_split(df, test_size=0.02, random_state=42)

# %%
# Save test and train dataset into two differnet files
train.to_csv('train_set.train',
             columns=["category_description"],
             index=False,
             header=False)

test.to_csv('test_set.train',
             columns=["category_description"],
             index=False,
             header=False)

# %%
# Fast text model
import fasttext

model = fasttext.train_supervised(input='train_set.train',
                                  dim=600,
                                  loss='hs',
                                  wordNgrams=3,
                                  lr=0.5,
                                  epoch=15,
                                  minn=3,
                                  maxn=5)

model.test('test_set.train')
# Out:
# (13917, 0.9552346051591578, 0.9552346051591578)

# %%
text = 'Bag Paper Kraft wine large'
text = preprocess(text)
model.predict(text, k=5)
# # # True L2 Class = Bags - Service - Disposable

# %%
model.save_model("../Models/L3/tuned_model.bin")

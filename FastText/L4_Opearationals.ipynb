# %%
# !pip install fasttext

# %%
# !pip install nltk

# %%
# Mounting Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Importing libraries
import pandas as pd
import numpy as np
import re

# %%
# Load the dataset
df = pd.read_csv('../../Datasets/fsa_prod_dump.csv', on_bad_lines='skip')
df.head()
# Out:
#   L0_Category            L1_Class                    L2_Category  \
# 0         NaN                 NaN                            NaN
# 1        Food  Food - Meat & Game        Beef -- Ground & Shapes
# 2        Food  Food - Meat & Game  Beef - Foodservice Whole Cuts
# 3        Food  Food - Meat & Game        Beef Deli & Charcuterie
# 4        Food  Food - Meat & Game        Beef Deli & Charcuterie
#
#    L3_Dictionary_SubCategory                  L4_dictionarySubgroup  \
# 0                        NaN                                    NaN
# 1       Beef (Bulk) - Ground        Beef Ground >10% Fat (NAMP 136)
# 2   Beef (Bulk) - Plate Cuts  Outside Skirt - Skinned (NAMP # 121E)
# 3  Beef - Deli & Charcuterie             Beef Pastrami (NAMP # 611)
# 4  Beef - Deli & Charcuterie             Beef Pastrami (NAMP # 611)
#
#                                  ProdName ItemCode                    Vendor  \
# 0    GROUND CHUCK FLAP 50% CHUCK NECK 50%      623  Golden Gate Meat Company
# 1       FINE GRIND BEEF TUBES 81/19 6/10#      624  Golden Gate Meat Company
# 2  AUST OUTSIDE SKIRT PEELED SOLD BY CASE     1717  Golden Gate Meat Company
# 3        PASTRAMI - NEW YORK STYLE- SABRA     1820  Golden Gate Meat Company
# 4      PASTRAMI SLICED 5# BAGS (50# CASE)     1821  Golden Gate Meat Company
#
#     ProdType
# 0  Canonical
# 1  Canonical
# 2  Canonical
# 3  Canonical
# 4  Canonical

# %%
# Separate dataset into 4 dataset based on L0_Category
# Preprocessing
# Droppig missing values
df = df.dropna(axis=0)

# Drop duplicates
df.drop_duplicates(keep='first', inplace=True)

# %%
df.L0_Category.unique()
# Out:
# array(['Food', 'Administrative', 'Operationals', 'Beverage'], dtype=object)

# %%
# Separate into 4 diffrent categories
df_food = df[df['L0_Category']=='Food']
df_administrative = df[df['L0_Category']=='Administrative']
df_operationals = df[df['L0_Category']=='Operationals']
df_beverage = df[df['L0_Category']=='Beverage']

# %%
print(df_food.L0_Category.unique())
print(df_administrative.L0_Category.unique())
print(df_operationals.L0_Category.unique())
print(df_beverage.L0_Category.unique())
# Out:
# ['Food']
# ['Administrative']
# ['Operationals']
# ['Beverage']

# %%
# Save into four different csv
df_food.to_csv('../../Datasets/food.csv', header=True, index=False)
df_administrative.to_csv('../../Datasets/administrative.csv', header=True, index=False)
df_operationals.to_csv('../../Datasets/operationals.csv', header=True, index=False)
df_beverage.to_csv('../../Datasets/beverage.csv', header=True, index=False)

# %% [markdown]
# # **L4 Category**

# %%
# Preprocessing fuction for category
def class_pre(text):
  new_text = re.sub(r'&', 'and', text)
  new_text = re.sub(r'[^\w\s]',' ', new_text)
  new_text = re.sub(r' +', ' ', new_text)
  new_text = re.sub(r'\s', '_', new_text)
  return new_text

# %%
# Replace all white spaces whith single space
# Remove white spaces in begining and end of the text
# Turn text into lower case

# Preprocessing Function
def preprocess(text):
    text = re.sub(r'&', 'and', text)
    text = re.sub(r'[^\w\s]',' ', text)
    text = re.sub(' +', ' ', text)
    return text.strip().lower()

# %%
# Cleaning function currently using
# import nltk
# from nltk.corpus import stopwords

# # Download stopwords
# nltk.download("stopwords")

# %%
# Did a slight modification, convert & into and
# Then removes extra whitespaces

# def clean(string):
#     string = re.sub('&', 'and ', string)
#     raw_text = re.sub("[^a-zA-Z]+", " ", string)
#     raw_text = re.sub(' +', ' ', raw_text)
#     raw_text = raw_text.strip()
#     words = raw_text.lower().split()
#     stops = set(stopwords.words("english"))
#     meaningful_words = [
#         word for word in words if ((not word in stops) and (len(word) >= 3))
#     ]
#     string = " ".join(meaningful_words)
#     return string

# %% [markdown]
# ## Operational

# %%
df = pd.read_csv('../../Datasets/operationals.csv')
df.head()
# Out:
#     L0_Category                                  L1_Class  \
# 0  Operationals         Operationals - Office & Financial
# 1  Operationals  Operationals - Production (BOH) Supplies
# 2  Operationals  Operationals - Equipment Incl Appliances
# 3  Operationals              Operationals - Guest & Staff
# 4  Operationals  Operationals - Production (BOH) Supplies
#
#                              L2_Category  \
# 0                        Office Supplies
# 1  Boards - Liners - Sheets - Disposable
# 2                  Equipment Maintenance
# 3                          Staff Apparel
# 4         Bags - Production - Disposable
#
#                  L3_Dictionary_SubCategory  \
# 0                       Packing - Shipping
# 1                      Food Wrapping Paper
# 2  Lubricants - Sealants - Other Chemicals
# 3        Apparel & Accessories - All Other
# 4                          Production Bags
#
#                            L4_dictionarySubgroup  \
# 0                                          Twine
# 1                Wax Paper - Bone Guard for Meat
# 2                                     Lubricants
# 3  Vendor Apparel - Hats - Aprons - T-Shirts Etc
# 4                               Vacuum Seal Bags
#
#                             ProdName ItemCode                    Vendor  \
# 0                       COTTON TWINE     9656  Golden Gate Meat Company
# 1    BONE GAURD WAX 9x150 FEET LONG"     9657  Golden Gate Meat Company
# 2               MINERAL OIL - GALLON     9663  Golden Gate Meat Company
# 3                GOLDEN GATE APPAREL     9672  Golden Gate Meat Company
# 4  CRY-O-VAC BAGS 8 X 10***1000/case     9680  Golden Gate Meat Company
#
#     ProdType
# 0  Canonical
# 1  Canonical
# 2  Canonical
# 3  Canonical
# 4  Canonical

# %%
# Counting L4 Category classes
len(df.L4_dictionarySubgroup.unique())
# Out:
# 1910

# %%
value_counts = df.L4_dictionarySubgroup.value_counts()
filtered_counts = value_counts[value_counts < 15]
print(filtered_counts)
# Out:
# L4_dictionarySubgroup
# File - Horizontal Tray Type                                                    14
# Clips - Bulldog                                                                14
# Spoon Rests                                                                    14
# Plugs or Stoppers for Non-Disposable Cup Lids                                  14
# Donut Box                                                                      14
#                                                                                ..
# Paper Bags - Flat Bottom - No Handle - White 1/6 BBL                            1
# File - Desktop Drawers                                                          1
# Wax Paper - Bone Guard for Meat                                                 1
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft Size Unspecified     1
# Labels - Subwrap                                                                1
# Name: count, Length: 563, dtype: int64

# %%
# Check value counts in a plot
# Import libraries
# import matplotlib.pyplot as plt

# # Get the values count
# counts = df.L4_dictionarySubgroup.value_counts()


# # Change the figure size
# # fig = plt.figure(figsize=(10, 15))

# for index, value in enumerate(counts.values):
#     plt.text(value + 1, index, str(value))

# plt.barh(counts.index, counts.values)
# plt.show()

# %%
# Checking the number of data points
df.shape
# Out:
# (250086, 9)

# %%
# making the category
df['L4'] = df['L4_dictionarySubgroup'].apply(class_pre)

# %%
# Making the category using labels into format
df['category'] = '__label__' + df['L4'].astype(str)

# %%
# Dropping irrelavant columns
columns = ['L0_Category', 'L4_dictionarySubgroup', 'ItemCode', 'Vendor', 'ProdType', 'L4']

# Dropping
df = df.drop(columns, axis=1)

# %%
df.head()
# Out:
#                                    L1_Class  \
# 0         Operationals - Office & Financial
# 1  Operationals - Production (BOH) Supplies
# 2  Operationals - Equipment Incl Appliances
# 3              Operationals - Guest & Staff
# 4  Operationals - Production (BOH) Supplies
#
#                              L2_Category  \
# 0                        Office Supplies
# 1  Boards - Liners - Sheets - Disposable
# 2                  Equipment Maintenance
# 3                          Staff Apparel
# 4         Bags - Production - Disposable
#
#                  L3_Dictionary_SubCategory                           ProdName  \
# 0                       Packing - Shipping                       COTTON TWINE
# 1                      Food Wrapping Paper    BONE GAURD WAX 9x150 FEET LONG"
# 2  Lubricants - Sealants - Other Chemicals               MINERAL OIL - GALLON
# 3        Apparel & Accessories - All Other                GOLDEN GATE APPAREL
# 4                          Production Bags  CRY-O-VAC BAGS 8 X 10***1000/case
#
#                                            category
# 0                                    __label__Twine
# 1            __label__Wax_Paper_Bone_Guard_for_Meat
# 2                               __label__Lubricants
# 3  __label__Vendor_Apparel_Hats_Aprons_T_Shirts_Etc
# 4                         __label__Vacuum_Seal_Bags

# %%
# Creating catehory description with producbt name and vendor
# df['category_description'] = df['category'] + ' ' + df['L1_Class'] + ' ' + df['L2_Category'] + ' ' + df['L3_Dictionary_SubCategory'] + ' ' + df['ProdName']
df['category_description'] = df['category'] + ' ' + df['L3_Dictionary_SubCategory'] + ' ' + df['ProdName']

# %%
# Drop used columns
columns = ['L1_Class', 'L2_Category', 'L3_Dictionary_SubCategory', 'ProdName']

df = df.drop(columns, axis=1)

# %%
# Apply preprocessing function to 'category_description'

df['category_description'] = df['category_description'].apply(preprocess)

# %%
# Test Train splitting
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.02, random_state=42)

# %%
# Save test and train dataset into two differnet files
train.to_csv('operationals_train.train',
             columns=["category_description"],
             index=False,
             header=False)

test.to_csv('operationals_test.train',
             columns=["category_description"],
             index=False,
             header=False)

# %%
# Fast text model
import fasttext

model = fasttext.train_supervised(input='operationals_train.train',
                                  dim=300,
                                  loss='hs',
                                  wordNgrams=2,
                                  lr=0.5,
                                  epoch=10,
                                  ws=15,
                                  minn=3,
                                  maxn=5)

model.test('operationals_test.train')
# Out:
# (5002, 0.9050379848060776, 0.9050379848060776)

# %%
text = 'Ladles - Spoons - Scoops SPOON REST white ceramic'
text = preprocess(text)
model.predict(text, k=5)
# Correct class - Shot machine
# Out:
# (('__label__spoon_rests',
#   '__label__basting_spoon_solid_not_perforated_',
#   '__label__spoons_non_disposable',
#   '__label__basting_spoon_perforated_or_slotted',
#   '__label__skimmers'),
#  array([0.43388844, 0.34116268, 0.14173618, 0.02561265, 0.01563608]))

# %%
model.save_model('../../Models/L4/operational/tuned_model.bin')

# %% [markdown]
# Selecting datapoints with for prediction

# %%
sample = pd.read_csv('../../Datasets/operationals.csv')
sample.head()
# Out:
#     L0_Category                                  L1_Class  \
# 0  Operationals         Operationals - Office & Financial
# 1  Operationals  Operationals - Production (BOH) Supplies
# 2  Operationals  Operationals - Equipment Incl Appliances
# 3  Operationals              Operationals - Guest & Staff
# 4  Operationals  Operationals - Production (BOH) Supplies
#
#                              L2_Category  \
# 0                        Office Supplies
# 1  Boards - Liners - Sheets - Disposable
# 2                  Equipment Maintenance
# 3                          Staff Apparel
# 4         Bags - Production - Disposable
#
#                  L3_Dictionary_SubCategory  \
# 0                       Packing - Shipping
# 1                      Food Wrapping Paper
# 2  Lubricants - Sealants - Other Chemicals
# 3        Apparel & Accessories - All Other
# 4                          Production Bags
#
#                            L4_dictionarySubgroup  \
# 0                                          Twine
# 1                Wax Paper - Bone Guard for Meat
# 2                                     Lubricants
# 3  Vendor Apparel - Hats - Aprons - T-Shirts Etc
# 4                               Vacuum Seal Bags
#
#                             ProdName ItemCode                    Vendor  \
# 0                       COTTON TWINE     9656  Golden Gate Meat Company
# 1    BONE GAURD WAX 9x150 FEET LONG"     9657  Golden Gate Meat Company
# 2               MINERAL OIL - GALLON     9663  Golden Gate Meat Company
# 3                GOLDEN GATE APPAREL     9672  Golden Gate Meat Company
# 4  CRY-O-VAC BAGS 8 X 10***1000/case     9680  Golden Gate Meat Company
#
#     ProdType
# 0  Canonical
# 1  Canonical
# 2  Canonical
# 3  Canonical
# 4  Canonical

# %%
drop_columns = ['L0_Category', 'L1_Class', 'L2_Category', 'ItemCode', 'Vendor', 'ProdType']
sample = sample.drop(drop_columns, axis=1)

# %%
sample.head(10)
# Out:
#                  L3_Dictionary_SubCategory  \
# 0                       Packing - Shipping
# 1                      Food Wrapping Paper
# 2  Lubricants - Sealants - Other Chemicals
# 3        Apparel & Accessories - All Other
# 4                          Production Bags
# 5                          Production Bags
# 6                          Production Bags
# 7                          Production Bags
# 8                          Production Bags
# 9                          Production Bags
#
#                            L4_dictionarySubgroup  \
# 0                                          Twine
# 1                Wax Paper - Bone Guard for Meat
# 2                                     Lubricants
# 3  Vendor Apparel - Hats - Aprons - T-Shirts Etc
# 4                               Vacuum Seal Bags
# 5                               Vacuum Seal Bags
# 6                               Vacuum Seal Bags
# 7                               Vacuum Seal Bags
# 8                               Vacuum Seal Bags
# 9                               Vacuum Seal Bags
#
#                                ProdName
# 0                          COTTON TWINE
# 1       BONE GAURD WAX 9x150 FEET LONG"
# 2                  MINERAL OIL - GALLON
# 3                   GOLDEN GATE APPAREL
# 4     CRY-O-VAC BAGS 8 X 10***1000/case
# 5  CRY-O-VAC BAGS 10 X 12*****1000/case
# 6   CRY-O-VAC BAGS 12 X 14****1000/case
# 7    CRY-O-VAC BAGS 14 X 16****500/case
# 8    CRY-O-VAC BAGS 14 X 20****500/case
# 9    CRY-O-VAC BAGS 16 X 24****500/case

# %%
uniques = sample.L4_dictionarySubgroup.unique()
for unique in uniques:
  print(unique)
# Out:
# Twine
# Wax Paper - Bone Guard for Meat
# Lubricants
# Vendor Apparel - Hats - Aprons - T-Shirts Etc
# Vacuum Seal Bags
# Liner - Garbage Bags Size Undeclared
# Corrugated Boxes (non Culinary Use)
# Wine Glasses - Whites
# Decanters - Wine
# Martini Glasses
# Coffee Filters
# Wine Glasses - Reds
# Champagne Flutes
# Water Glasses - Stem
# Cleaner - Ice and Beverage Equipment
# Paper Filters
# Whisky Glasses
# Tea Chests - Boxes
# Polishing Cloth
# Cocktail Glasses
# Floorstanding Upright Freezers
# Wine Glasses - All Other
# Countertop Display Freezers
# Water Glasses
# Coffee Equipment Chemical Cleaners
# Shot Machine
# Tableservice Espresso Cups and Saucers
# Wine - Ice Buckets and Chillers
# Beer Glasses
# Cold Drink Cups - All Other
# Lids Only - for Cups - Disposable
# Hot Drink Print Cups
# Shot Glasses
# Old Fashioned Glasses
# Hiball Glasses
# Tumbler
# Wine Bags
# Beverage Dispensers
# Mugs
# Brandy Glasses
# Cups Disposable
# Tableservice Cappuccino Cups and Saucers
# Coffee Equipment Parts
# Demitasse Spoon
# Wine Preservation Systems
# Ashtrays
# Decanters
# Mixing Glasses
# Rocks Glasses
# Cup Sleeves - Collars - Jackets
# Ice Cream Cone Dispensers
# Straws
# Dessert Cups and Lids
# Resealable Bags
# Ladles
# Cleaner - Fruit & Vegetable Wash
# Pepper Shaker
# Water Treatment
# Acetate Strips
# Tenderizer
# Manual Slicers - Cutters - Potato - Fry Cutters
# Disposable Food Pans
# Food Container Lid - Disposable
# Disposable Food Pan or Platter Lids
# Foil Wrap
# Baking Cups - Disposable
# Food Container - Disposable - Takeout Box - Single Compartment with Lid
# Disposable Aluminum Steam Table Pans and Lids
# Food Trays or Carriers - Disposable - Multi-Compartment
# Food Container - Disposable - Takeout Box - Catering
# Food Container - Disposable - Takeout Oblong
# Disposable Pie Pans (aka Plate)
# Disposable Cake - Cookie or Pizza Pans and Lids
# Roast Pan
# Aprons
# Bib - Adult
# Caps
# Hair Nets
# Chefs Hats
# Mitts And Pads
# Janitorial and Cleaning Gloves
# Gloves - Vinyl / Synthetic - Powdered
# Gloves - Vinyl / Synthetic - Powder Free
# Oven and Hot-Handling Gloves
# Gloves - Poly - Powder Free
# Respiratory Protection Particle Masks and Filters
# Gloves - Nitrile - Powder Free
# Cut Resistant Gloves
# Sandwich Bags
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft #2
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft #4
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft #6
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft #8
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft #10
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft #12
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft #16
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft #25
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft 1/6 BBL
# Shopping Bags with Die Cut Handle
# Liquor and Wine Bags
# Shopping Bags with Twist Handle - Paper - Natural/Brown/Kraft
# Shopping Bags with Twist Handle - Paper - Other Colors
# Paper Bags - Flat Bottom - No Handle - White #6
# Paper Bags - Flat Bottom - No Handle - White #8
# Paper Bags - Flat Bottom - No Handle - White #20
# Liner - Garbage Bags - Under 20 Gal
# Liner - Garbage Bags - 20 to 40 Gal
# Liner - Garbage Bags - Over 40 Gal
# French Fry Bags
# T-Shirt Bags
# Food Storage Bags - Clear Poly or Cellophane
# Crayons
# Bun Pan Rack Cover Bags
# Portion Bags
# Steam Table Pan Covers
# Freezer Bag - Resealable
# Paper - Copy and Printing - White
# Boards for Cake Boxes
# Pan Liners
# Food Pan Liners - Disposable
# Pizza Liners
# Parchment Paper
# Bowls
# Food Container - Disposable - Takeout Round Incl Deli
# Bowl Lids - Disposable
# Food Container WITH LID - Disposable - Takeout Round Incl Deli
# Food Container - Disposable - Takeout Container - Hoagie
# Plates - Disposable
# Plates WITH Lid
# Food Container Lid - Disposable - Takeout Round Incl Deli
# Production Food Storage Containers - Round Cover - Lid
# Food Container Lids Only - Disposable - Takeout Box
# Food Trays or Carriers - Disposable - General Use
# Sandwich Boxes
# Plates - Disposable - Multi Compartment
# Food Container - Disposable - Takeout Box - Clamshell
# Disposable Food Platters & Trays
# Production Food Storage Containers Cover - Lid
# Food Container - Disposable - Takeout Box - Multi-Compartment
# Bakery Boxes - Containers
# Cake Boxes - Containers and Lids
# Pizza Boxes
# Pizza Saver for Pizza Box
# Pie Box or Container
# Boards for Pizza Boxes
# Birthday Candles
# Tapered Candles
# Pillar Candles
# Venetian Candles
# Candle And Lamp Globes
# Cartridge - Cell Liquid Wicked Candles
# Candle Holders
# Votive Candles
# Tea Candles
# Torch
# Urinal Screens
# Corn Brooms
# Angler Brooms
# Brush - Kitchen Pot and Kettle
# Push Brooms
# Handle Brooms
# Mop Handles
# Utility Brushes
# Deck and Floor Brushes
# Grill - Griddle Brush
# Toilet Brushes
# Dust Pans
# Dust Mops
# Mop Frames
# Round or Square Brute or Huskee Type Waste Containers
# Trash Dollies
# Cleaner - Grill
# Scour Pads
# Grill - Griddle Brick
# Grill - Griddle Screens
# Grill - Griddle Pads
# Grill - Griddle Pad Holders - Handles
# Cleaning Bucket - Pail
# Combo Bucket and Wringer
# Signs - Floor
# Mop Heads
# Wet Mops - Loop
# Bucket Wringer
# Plungers
# Scrubber Pads
# Scrubbers
# Sponges
# Floor Squeegees
# Window Squeegee
# Rectangular Slim Jim Type Waste Containers
# Recyclables Waste Containers and Lids
# Cold Drink Print Cups
# Cups Disposable - Stock Printed
# Hot Drink Cups
# Beverage Dispenser Type Carriers and Accessories
# Hot or Cold Cups
# Translucent Cups
# Cold Drink Cups - Clear Plastic
# Shooter Cups
# Kids Cups
# Wine and Champagne Cups - Glasses
# Water Cups
# Hot Drink with Handle Cups
# Food Container with Lid - Production
# Soup Cups and Lids Disposable
# Soap - Sanitizer Dispenser
# Food Cups
# Food Container - Disposable
# Soup Cups
# Portion (aka Souffle) Cups & Lids Disposable
# Container Inserts
# Chopsticks
# Ball or Bead Picks - Skewers
# Paddle Picks
# Prism Picks
# Arrow Picks
# Forks - Disposable
# Tongs and Parts
# Knives - Disposable
# Spoons - Disposable
# Cutlery Kits - (Utensils Only) NO Napkin
# Cutlery Kits -  (Utensils Only) WITH Napkin
# Cutlery Kits - Utensils with S & P and/or Sweetener or Creamer
# All Purpose Knife
# Catering Tasting - Appetizer Spoons - Disposable
# Sandwich Picks
# Skewers
# Steak Markers
# Balloons
# Stirrers
# Stirrer Straws
# Frill Pick
# Toothpick
# Doilies - Linen Like (Paper)
# Production Condiment Dispensers
# Dispenser Parts - Production Ingredient Dispensers
# Pump Dispenser and Parts
# Napkin Dispensers
# Towels Dispensers
# Spray Bottles and Lids
# Toilet Seat Cover Dispenser
# Folded Towels Dispensers
# Roll Towel Dispensers - Wall Mount
# Lemon Wrap
# Napkin for Dispenser
# Napkin - Cocktail (Beverage)
# Facial Tissues
# Napkin - Luncheon or Medium
# Napkin - Dinner or Large
# Textile Napkin Bands & Rings
# Napkin Band - Ring
# Textile Linen Napkins
# Serving Buckets - Pails
# Food Cups and Lids
# Disposable Meal Tray Liners and Mats
# Placemat - Disposable
# Chafer Fuel
# Propane Fuel
# Food Warmer - Flameless
# Charcoal
# Fire Starter
# Wood
# Cheesecloth
# Labels - Food Rotation Day-centric
# Labels - Food Rotation Non-Day-centric
# Binder
# Wire Shelf
# Labels - Food Information Non-Rotation
# Single Copy Checks and Forms
# Multi-Copy Checks and Forms
# POS and Cash Register Tape (Paper Rolls)
# POS and Cash Register Ribbon
# Light Bulbs - Heat Lamps
# Food Bags - Production
# Grease Filters (NON Paper)
# Filter Holders - Water or Air
# Flex Straws
# Bar - Cocktail Straws
# Butcher Paper
# Tablecloth - Tablecover - Disposable
# Toilet Seat Covers
# Toilet Paper
# Foodservice Wipers - Reusable  but not Launderable
# Disinfecting - Sanitizing Surface Wipes (Not personal use)
# Cleaner - Degreaser
# Paper Towels - Folded
# Limited Life Launderable Foodservice Wipers & Cleaning Towels
# Paper Towels - Roll
# Paper Towels - Center Pull
# Individually Packaged Towelette Moist Wipers
# Fast Food - Cafeteria - Healthcare - Cell Meal Trays and Lids
# Food Container - Disposable - Deli Container - Hinged (Clamshell)
# Cafeteria - School Tray - Multi-compartment Disposable
# Disposable Food Platters & Trays with Lids
# Food Container - Disposable - Takeout Box - Clamshell - Multi-Compartment
# Beverage Drink Boxes and Cup Carriers
# Food Container - Disposable - Takeout Box - Multi-Compartment with Lid
# Food Trays or Carriers - Disposable - Specialty
# Food Trays or Carriers - Disposable - Hot Dog
# Wax Paper
# Film Wrap
# Sandwich - Deli Wrap
# Deli Bags
# Freezer Wrap
# Patty Wrap - Paper - Dividers
# Tape - Masking
# Tableservice Plates - Multi Use
# Tableservice Platters - 12.99 Or Under"
# Tableservice Serving Bowls (Individual)
# Tableservice Bouillon Cups
# Tableservice Soup Bowls - Crocks
# Tableservice Bowls
# Tableservice Ramekins
# Mugs - Coffee
# Teapots
# Serving Plates
# Tableservice Platters - 13 To 22""
# Coffee Cups (No Lid)
# Tableservice Saucers
# Flower Vases
# Carafes
# Pitchers
# Pilsner Glasses
# Glasses
# Glasses - NA Bev - Etc Incl Branded - Logoed
# Goblet
# Jiggers
# Champagne Glasses (Not Flutes)
# Cordial - Sherry - Port Glasses
# Tableservice Dessert - Fountain Sherbet
# Cooler Glasses
# Beverage Cups
# Bottle Stopper - Champagne
# Bar Caddy
# Bar Spoons
# Bar Muddlers
# Bar Strainers
# Corkscrews - Waiters
# Bar Shakers
# Bar Mats
# Bar Store and Pour Lids and Spouts (Neck)
# Pourers Liquor
# Pourers Liquor Whiskey Gate
# Pourers Liquor Control Measure
# Serving Basket
# Tableservice Service Baskets
# Call Bell
# Airpots and Airpot Parts
# Beverage Insulated Servers
# Bar Mixer - Blender
# Blender Parts
# Mixing Bowls
# Cutting Board
# Bus Bins Cover - Lid
# Bus Bins - Totes
# Pastry Brushes
# Guest Hand and Nail Brushes
# Buffet Service Spoons
# Dome Lids for Bakery Items
# Pastry Tips and Couplers
# Pastry Bags
# Bag Dispensers
# Bottle Openers
# Manual Can Openers & Parts
# Hand Held Can Opener
# Carts - Bussing and Utility
# Production Area Mats
# Strainers
# Coffee Pots - Servers
# Dish Tables
# Colanders
# Condiment Dispensers
# Meat Thermometers
# Refrigerator - Freezer Thermometers
# Oven Thermometers
# Butane Fuel
# Butane Stick Lighters
# Burner - Hot Plate
# Lobster - Crab Crackers
# Tableservice Creamers
# Table Crumber
# Cutting Tools (Box Knives - Utility Knives - Blades - etc)
# All Other Dishwashers
# Hood Vent - Exhaust
# Sheet-Pan - Tray Racks (aka Bun Racks)
# Production Shelving
# Cooling Paddles
# Cutting Board Racks
# Squeeze Bottle
# Undercounter Dishwashers
# Bar Electric Glass Washers
# All Other Dishwashers Parts
# Heater Booster
# Manual Slicers - Cutters - Mandolins
# Scoops - Ice Cream
# Dishers
# Conveyor Dishwashers
# Conveyor Dishwasher Parts
# Dredges
# Manual Slicers - Cutters - Egg Slicers
# First Aid Cabinet or Kit
# Finger Cot
# Tableservice Salad Forks
# Tableservice Forks
# Tableservice Knives
# Tableservice Dessert Spoons
# Tableservice Tea Spoons
# Tableservice Soup Spoons
# Tableservice Bouillon Spoons
# Tableservice Cocktail - Oyster - Seafood Forks and Picks
# Serving Spoons
# Tableservice Dessert Forks
# Tableservice Tablespoons
# Bar Mixologist Set
# Urinal Mats
# Knife Sharpener - Manual - Steel
# Shelving Parts
# Labels - Holders / Shelf Tags
# Blenders - Immersion / Stick
# Salad Spinner and Parts
# Food Processors and Mixers
# Spice Grinder
# Food Processor and Mixer Parts
# Food Mills
# Production Food Storage Ingredient Bins
# Production Food Storage Boxes
# Production Food Storage Boxes - Cover - Lid
# Ice Only Bucket - Lid
# Production Food Storage Containers - Round
# Production Food Storage Container
# Buffet Service Serving Utensils
# Production Forks (Pot Forks - Cooks Forks)
# Floorstanding Fryer Baskets
# Fry Pans
# Funnels
# Glass Rimmers and Parts
# Bar Glass Brushes
# Sheet Pan
# Steam Table Pans
# Graters
# Production - Check - Ticket Spike
# Production Window - Check Slide (Rail Type)
# High-Chairs - Infant Seats
# Dining Area Table Leveler
# Knife Holders - Racks including Parts
# Knife Sharpener - Manual - Stone or Ceramic
# Chef Knife
# Paring Knife
# Oyster Knives
# Tableservice Steak Knives Other Handle
# Tableservice Steak Knives Wood Handle
# Serrated Knife
# Slicing Knife
# Bread Slicing Knife
# Cook Knife
# Zesters
# Sandwich Knife
# Pie - Cake Servers
# Roll Bag Knife
# Kits Knife
# Spoodles
# Potato and Bean Mashers
# Measuring Spoons
# Measuring Cups
# Baller - Cutter
# Mixing Cups
# Mixing Paddles
# Baking Mats
# Sauce Pan
# Peelers
# Pepper Mills - Grinders
# Salt And Pepper Grinders
# Salt And Pepper Shakers
# Pizza Cutters
# Pizza Peels
# Pizza Pan - Screen
# Pizza Trays
# Brazing - Casserole
# Tableservice Sauce Cups
# Pasta Cooker Pots
# Stock Pots
# Heat Resistant Pan Grips - Holders
# Faucet and Hose Parts
# Hoses
# Faucets
# Pre-Rinse Units and Parts & Accessories
# Banquet Tables
# Glasses Storage and Wash Rack
# Servingware Flatware Holder Bins
# Pre-Soak - Warewashing
# Portion Scales
# Digital Scales
# Scoops
# Spatulas
# Dough Cutters
# Scrapers
# Grill - Griddle Scrapers
# Grill - Griddle Scraper Blades
# Syrup Dispensers
# Filter Cartridges - Water or Air
# Cheese Shakers
# Shears
# Sieves
# Servingware Flatware Holder Cylinders
# Servingware Flatware Holder Boxes
# Overflow Pipes
# Platter - Sizzler Ovenware
# Bar Juicer Manual
# Skimmers
# Turners
# Spoons - Non-Disposable
# Spreaders
# Squeeze Bottle Lid
# Tray Stands
# Hamburger - Steak Grill - Griddle Weights
# Steam Table Adapter Plate and Bars
# Production Food Storage Pans
# Production Food Storage Pans Cover - Lid
# Bain Marie
# Wedgers
# Countertop Toasters & Parts - All Other
# Bain Marie - Vegetable Insets and Lids
# Double Boilers and Parts
# Pot and Pan Covers
# Bar Store and Pour Containers
# Buffet Service Chafers - Warmers
# Vacuum Sealer Machine
# Coffee Brewers
# Dish Racks - Extenders
# Plate - Tray Racks
# Waterproof Dish Machine Thermometer
# Timers
# Candy Thermometers
# Pocket (Pen Style) Test Thermometers
# Non Contact Thermometers
# Steam Tables
# Corers
# Bar Mop Towels
# Dish Towels
# Tableservice Serving Trays - Platters
# Manual Sweeper
# Whipped Cream Dispenser
# Water Filters
# Seltzer - Soda Charges
# Whippet Charges for Dispensers
# Mixing Whips
# Food Warmer - Well Style (Excluding Soup)
# Soup Kettles - Warmers - Rethermalizers
# Countertop Microwave Ovens
# Cleaner - Oven and Grill
# Rinsing Agent - Warewashing
# Detergent - Warewashing - Machine
# Dish Sanitizer
# Cleaner - Surface
# Cleaner - Floor
# Cleaner - All Purpose
# Disinfectant
# Bleach
# Polish - Metals
# Cleaner - Bathroom General
# Cleaner - Drain
# Polish - Furniture
# Cleaner - Wood
# Cleaner - Glass - Window
# Pest Control - Chemicals
# Pest Control - Fly Strips
# Sanitizer
# Detergent - Laundry - Powder - Bulk
# Detergent - Laundry - Liquid
# Detergent - Pot and Pan
# Sanitizer Test Strips
# Cleaner - Oven
# Cleaner - Fryer and Grill
# Bathroom Deodorizer
# Odor Eliminator
# Air Freshener - Odor Control - Aerosols and Sprays
# Urinal Blocks
# Hand Soap and Hand Sanitizer
# Dish Soap
# Liquid Body Soap
# Descaler - Delimer
# Dish Stain Remover - Destainer
# Detergent - Presoak
# Toilet Tissue Dispensers
# Restaurant Table Service Trays
# Gloves - Latex - Powdered
# Gloves - Latex - Powder Free
# Safety Goggles
# Tableservice Asian Zest - Tasting - Soup Spoon
# Ph Test Strips
# Gloves - Latex - Unlined
# Dish and Pot-Washing Gloves
# String & Twine
# Carry Out - To Go - Doggie Bags
# Wood Oil Incl Butcher Block
# Disposable Compartment Trays
# Shopping Bags with Handle - Non Paper
# Gloves - Vinyl and Nitrile Blend (Vitrile) - Powder Free
# Eyewear - Glasses - Goggles - Face Shields
# Boxes - Food
# Beverage Container Liners
# Popcorn Machine - Countertop
# Bakery Bags (Finished Product)
# Bakery Molds
# Floor Standing Display Cases
# Cups Disposable - Brand Printed
# Rolling Pins
# Dippers
# Envelopes_DO NOT USE
# Mechanical Scales
# Mop Buckets
# Spoonulas
# Waste Baskets
# Sunscreen
# Rigid Trash Can - Rigid Waste Receptacle Liner
# Toothpaste
# Air Freshener Dispenser
# Guest Bath Mat
# Lotion
# Face Soaps Cleansers and Creams
# Popsicle - Frozen Treat Sticks
# Laundry Starch
# Cough and Sore Throat Products
# Popcorn Bags
# Floorstanding Grill Parts and Accessories
# Straws - Edible
# Pallets
# Display Racks
# Countertop Display Cases
# Vitamins and Supplements
# Lip Balm
# Kiddie Activity Supplies (not Books or Crayons)
# Salt Shaker
# Cooking Bags
# Popcorn Boxes or Tubs
# Cutting Board Allergen System Kit
# Tray Lids
# Tableservice Dinner Plates
# Condiment Station Inserts
# Pie - Cake Stands
# Heat Lamps
# Basting Spoon - Solid (not perforated)
# T-Shirt Bags Dispensers
# Food Trays or Carriers - Disposable - Food and Cup Holder Combo
# Table Service Dinner Plates - Multi Compartment
# Tableservice Dessert - Plates
# Serving Dishes - Multi Use Mini - Sampling - Tasting
# Food Warmer - Merchandiser Style
# Tableservice Salad Service Plates
# Casseroles and Lids Ovenware
# Detergent - Laundry - Pods
# Flights Trays & Paddles
# Display Bowls - Crocks - Pans
# Pizza Racks
# Organizer - Condiment Bins
# Floor Stripping or Sanding Pads
# Wet Mops
# Tableservice Plate - Tray Underliners
# Cups - Non-Disposable
# Tableservice Butter Knives
# Placemat
# Grill Pans
# Cupcake or Muffin Box
# Candle & Lamp Parts & Accessories
# Fabric Softener - Conditioner
# Sauce Pot
# Cleaner - Bathroom - Bowl
# PPE Clothing Dispensers
# Countertop Hot Dog Grills
# Ice Melt - De-Icer
# Tableservice Salad Service Bowls
# Cocktail Disposable Cups
# Egg Poachers
# Basting Spoon - Perforated or Slotted
# Cap - Bouffant
# Lobby Brooms
# Rarebits Ovenware
# Water Filter Systems
# Air Freshener - Odor Control - Solid/Gel
# Display Basket
# Rice Cooker
# Tableservice Dessert - Glass
# Rack Parts and Accessories
# Cold Food Tables
# Polish - Floor
# Laundry Scent Booster
# Insulated Pan Carriers
# Serving Forks
# Floorstanding Griddles Parts and Accessories
# Food Storage Shelf Drain Pan
# Putty Knife
# Buffet Service Cold Pans - Crocks
# Drying and Storage Racks
# Hot Water Boiler Dispenser
# Tableservice Bread Plates
# Food Display Platters - Trays
# Gloves - Nitrile - Powdered
# Sugar Dispensers - Shakers
# Trays
# Shoe Covers
# Non-Disposable Cup or Glass Lids
# Thermometer and Sanitizer Test Kit
# Tableservice Bouillon Bowls
# Serving Bowls (Sharable)
# Bowl WITH Lid
# Labels - Blank (Non office use)
# Glass Sanitizer
# Tiles and Templates for Steam Tables or Buffets
# Production Food Storage Ingredient Bins Cover - Lid
# Motor Oil
# Condiment Station - Counter
# Steak Paper
# Tip Trays
# Candle Lamps
# Choppers - Chopper Blades - Accessories
# Tableservice Plate Covers - Lids
# Hot Dog Dish - Tray
# Cup Dispenser Parts
# Manual Slicers - Cutters
# Flatware Racks
# Bowl Mops
# Corkscrews- Winger
# Industrial - Shop Wipers
# Buffet Service Plates
# Trivets
# Cruets and Parts
# Laundry Whitener - Stain Control
# Heating - Holding Cabinets
# Non-Disposable Cap Lids
# Display Stands
# Glassware - Jars
# Floorstanding Ice Bin - Mobile Caddy
# Coffee Grinders
# Coffee Warmers
# Tableservice Gravy - Sauce Boat
# Tableservice Salad Service Crocks
# Brooms
# Display Crate or Box
# Tableservice Sauce or Dipping Bowls
# Countertop Rotisserie Oven
# Gloves - Nitrile - Flock Lined
# Posters
# Condiment Racks - Tabletop
# Dunnage and Floor Racks
# Training Supplies
# Gloves - Latex - Flock Lined
# Round or Square Brute or Huskee Type Waste Container Lids
# Delivery Carriers - Thermal Bags
# Oyster Plates
# Beer Tap Plug
# Decanters - Wine - Portion Serving
# Buffet Service Trays
# Menu Tissue
# Floor Kits
# Pizza Oven Brush - Scraper
# Cart Parts and Accessories
# Pasta Baskets
# Sanitary Napkin Waste Receptacle
# Air Filters
# Salad Dressing Dispenser Collar
# Religious Candles
# Sanitary Napkin Dispenser
# Beverage Service Lids
# Buffet Service Riser - Display
# Step On Waste Receptacles
# Production Food Storage Jars
# Parasol Picks
# Juice Glasses
# Plate Lids - Disposable
# Bar Glass Washers & Parts
# False Bottom Pots and Pans
# Tableservice Dessert Knives
# Ice Cream Scoop Dipper Well and Parts
# Hood Filters
# Laundry Hamper
# Pail Openers
# Tableservice Spoons
# Serving Boards
# Candles All Other
# Au Gratin Ovenware
# Carts - Food Serving
# Plastic - Foil Wrap Dispensers
# Cigarette Urns and Smoking Receptacles and Parts
# Portable Serving Bars
# Beverage Tubs
# Signs - Table or Counter Setting
# Markers - Dry erase
# Mesh Bags - Produce & Shellfish
# Novelty Picks
# Wet Mops - Cut End
# Tableservice Sauce Plates
# Food Warmer - Strip Style Hanging Heater
# Coaster - Bar and Drink
# Pitcher Ice Core
# Floor Pads
# Portion Control Measure
# Batter Dispensers and Parts
# Bakery Tissue
# Signs - Wall
# Silverware Savers
# Gloves - Nitrile - Unlined
# Buffet Service Plate Dispensers and Parts
# Basting Brushes
# Laundry Stain Remover
# Hair Removal Cream
# Shaker - Dispenser Lids
# Trucks and Dollies
# Dish - Baking Ovenware
# Stock Tank
# Label Dispensers
# Serving Utensils - Disposable
# Rack and Cabinet Covers
# Waste Container Lids
# Dutch Oven
# Thermometers
# French Fry Scoop
# Steam Kettle
# Skillets
# Manual Slicers - Cutters - Blades & Accessories
# Silverware Bags
# Sous Vide Equipment and Parts
# Cup - Lid Organizers
# Engine Additives & Treatments
# Tableservice Platters
# Tilt Truck Trash Bin
# Carving Station - Counter
# Cup Dispensers
# Sticky Notes
# Tissue Dispenser
# Cups
# Air Freshener - Odor Control - Cartridges with Fluids
# Disposable Meat - Supermarket Trays
# Rectangular Slim Jim Type Waste Container Lids Only
# Tableservice Seafood Service Snail Service
# Cutlery Sleeve - Pouch
# Food Dish - Tray - Multi Use Mini - Sampling - Tasting
# Sign Holders - Tabletop (not Tabletents)
# Knotted Picks
# Purse Hooks
# Pasta Cooker
# Food Container - Disposable - Food Cone
# Cleaning Tools - Kits
# Tableservice Platters - 23 And Up"
# Fuses
# Countertop Pizza Ovens
# Buffet Service Punch Bowls
# Stands - Presentation
# Bottle Brushes
# Gloves - Canvas
# Soup - Hot Cereal Tureens and Lids
# Waste Bin - Receptacle Parts
# Hot Dog Bags
# Cleaning Caddy Bin
# Cleaner - Carpet
# Hurricane Glasses
# Hot Food Tables
# Loaf Pans
# Menu Covers
# Disposable Loaf Pan
# Ramekins Ovenware
# Pot -Pan- Bowl Racks
# Non-Disposable Bowl Lids
# Swing Top Waste Receptacles
# Diapers
# Soaped Pads
# Labels - Tamper Resistant
# Allergen - Diet Picks
# Sleeves
# Boots
# Deodorant
# Tableservice Dessert - Dish
# Laminate
# Cruet Rack
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft #20
# Sword Picks
# Cookie Bags
# Extension Poles - Handles
# Mouthwash
# Menu Holders
# Folded Towels Dispensers - Wall Mount
# Countertop Beverage Refrigerators
# Sporks - Disposable
# Mops
# Dispenser - Cups and Lids
# Production Food Storage Jar Lids - Covers
# Bib - Child
# Table Numbers - Number Tents
# Woks - Stir Fry
# Tableservice Dessert - Fountain Sundae
# Glove Dispensers
# Room Service Trays
# Cutting Mat
# Vacuum Attachments
# Loop PIcks - Skewers
# Screwdrivers
# Baby Wipes
# Indoor - Outdoor Waste Receptacle
# Lint Roller
# Water Serving Bottles
# Light Bulbs All Other
# Production Cleaning Dusters and Parts
# Guest Tables - Parts and Accessories
# Cup & Saucer
# Production Food Storage Drain Tray
# Production Food Storage Container with Lid
# Ice Bags
# Carts - Dish
# Ear Plugs
# Juicers
# Check Holders - Presenters
# Half Round Waste Containers
# Popcorn Cups
# Thermometer Probes and Accessories
# Inspection Gloves
# Countertop Induction Electric Stoves
# Tableservice Butter Dish - Plate
# Hamburger - Basting Dome Cover
# Tea Cups
# Beverage Service Sugar Pack Holders
# Wet-Nap - Wipe Dispensers
# Chopstick Holders
# Sealer - Floor
# Disposable Chafer Stands and Kits
# Sanitary Napkins
# Display Case - Shelf Liners
# Receiving Scales
# Seasoning - Spice Shakers
# Bakery Decorating Sets
# Gloves - Work / Material Handling / Utility - Any Material
# Paper Wrap Dispensers
# Wet Mop Pads
# Waffle Iron
# Sauce - Souffle Ovenware
# Carts - Beverage Serving
# Griddle Pans
# Egg Containers and Lids
# Pizza Stands (for Table)
# Mop Hanger
# Cleaner - Auto - Car
# Plastic - Foil Wrap Dispenser Parts
# Candle And Lamp Shades
# Serving Bar Parts and Accessories
# Safety Pins
# Tableservice Salad Service Crock Lids
# Squeeze Out Dispensers
# Disposable Ovenable - Baking Food Tray or Ramekin
# Carts - Janitorial
# Countertop Stove Parts and Accessories
# Dispenser Parts
# Bar Blender Parts
# Dehydrators
# Beverage Equipment Parts
# Food Warmer Parts
# Ice Scoop Holder
# Crowd Control - Rope - Posts - Parts and Accessories
# Dome - Open Top Waste Containers and Lids
# Countertop Fryer Baskets
# Lamp Parts
# Dinner Knife
# Over The Counter Medicines
# Safety Bag Opener
# Beverage Bottle - Jug
# Hot Drink Lid Plug Stopper
# Bottle Stoppers
# Buffet Service Chafers - Warmers - Parts And Accessories
# Buffet Service Bowls
# Safety Apparel
# Machine Oils & Lubricants - Countertop Appliances
# Textile Dinner Napkins
# Pot and Pan Sets
# Candle And Lamp Bases
# Cereal Dispensers
# Liner - Sanitary Receptacle
# Fabric Refresher
# Sewing Kit
# Safety Mat
# All Purpose Dispensers
# Blade Replacements (Culinary Type - NOT for Tools)
# Coffee and Tea Urns
# Electric Slicers - Cutters Parts & Accessories
# Tableservice French Fry Cup - Basket - Holder
# Locks
# Beard Protectors
# Work - Production Tables
# Broom Handle Only
# Countertop Broilers
# Tart Pan
# Paper Bags - Flat Bottom - No Handle - White #25
# Write On White Boards / Dry Erase Boards
# Cables (Phone - Cat 5 - Coaxial - etc)
# Beverage Bottle Lids
# Signs - Hanging
# Menu Paper
# Chlorine Test Strips
# Floorstanding Mixers
# Decanters - Coffee
# Butter Melter
# Buffet Service Condiment Pumps
# Chefs Jackets
# Food Trays or Carriers - Disposable - Taco
# Manual Slicers - Cutters - Cheese Slicers
# Chicken Boxes - Buckets - Containers
# Shelving Posts - Uprights
# Beverage - Water Dispensers
# Beverage Thermometers
# T-Stick Thermometers
# Cappuccino - Espresso Machine
# Hot Beverage Machine
# Pasta Cooker Inserts
# Absorbent Spill Supplies
# Eye Wash Station And Supplies
# Bar Equipment Parts
# Serving Bar Sneeze Guards and Parts
# Snack Bags
# Non-Disposable Platter - Tray Lids
# Buffet Service Ice Molds - Trays
# Coffee Knock Box
# Plate Warmers
# Erasers
# Shaving Cream - Gel and Aftershave
# Countertop Convection Ovens
# Pizza Plate
# Syrup Dispenser Lids
# Wet Mops - Screw
# Bake Pans
# Wall Thermometers
# Storage Cabinets
# First Aid Kit Refills
# Mop Bucket Parts
# Cleaner - Specialty (Gum - Graffiti - Goo - etc)
# Teapot Lids
# Filter Powders - Water or Air
# Pie Pans
# Wet Wipes for Hands
# Collins Glasses
# Buffet Service Display Lids
# Thermocouple Thermometers
# Potato Ricers
# Countertop Steamers
# Table Runners
# Tableservice Bread Baskets
# Dispenser Parts - Table & Shaker Dispensers
# Menu Cards - Small Signs
# Guest Paper Towels
# Kitchen Rags & Cloths
# Fish Bowls
# Markers for Pies and Cakes
# Food Container - Disposable - Takeout Container - Sushi
# Juicers - Reamers
# Pest Control - Supplies & Equipment
# Cookie Boxes
# Steel Wool Pads and Scrubbers
# General Maintenance Rags & Cloths
# Drinkware Lid
# Fry Pan Server Ovenware
# Grate Drains - Wire for Pans
# Countertop Sandwich Grills
# Buffet or Display Bowl - Tray Liners
# Carafe Lids
# Bar Liners
# Rubber Bands
# Kiddie Activity Books
# Cleaver
# Corkscrew - Counter or Wall Mount
# Lid Dispensers
# Pencil - Non Colored
# Cat Litter
# Chemical and Cleaner Dispensers
# Multi-Copy Carbon Checks and Forms
# Beverage Bottle - PET Bottle
# Horizontal Baby Changing Table
# Laundry Sour - pH Control
# Napkin Holders
# Tableservice Table Caddy
# Bread Boards For Dining Room
# Bun Pan Bags
# Dust Cap
# Storage Bins - Totes - Non Food Related
# Paper Bags - Flat Bottom - No Handle - White #12
# Cake Pans
# Tableservice Side Dishes
# Food Trays or Carriers - Disposable - Bento
# Air Freshener - Odor Control - Fluids (non Aerosol)
# Signs - Floor Standing
# Countertop Panini Griddle
# Lid - Straw Dispensers
# Personal Massager
# Lunch Boxes
# Cotton Candy Bags
# Labels - Dishwasher Temp
# Dough Proofing and Storage Pans
# Tableservice Knife - Fork - Spoon Sets
# Countertop Roaster Ovens
# Beverage Bags Incl Cocktails-to-Go
# Steamer Baskets
# Hazard - Spill Cleanup Kits
# Margarita
# Electronic Wipes - Screen - Monitor - Lense
# Tape - Duct / Repair
# Batteries - All Other
# Muffin Pans
# Cooling Thermometers
# Tableservice Dessert - Cup
# Frozen Beverage Machine
# Cooling Rack
# Countertop Griddles
# Thumbtacks
# Toilet Seat Bands
# Healthcare Pellet Warmers
# Cash Register Stands
# Countertop Griddles Parts and Accessories
# Vacuum Wrap Film
# Boards
# Tape Dispensers
# Netting
# Envelopes - Clear / Packing List
# CO2 Pads
# Paperboard Slip Sheets - Boards
# Tape - Film / Magic / Transparent
# Sand Paper
# Counter - Bench Brushes
# Sink Parts
# Cleaner - Stainless Steel
# Cleaner - Freezer
# Meat Wrap
# Packing Foam
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft 1/7 BBL
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft 1/8 BBL
# Paper Bags - Flat Bottom - No Handle - White #10
# Paper Bags - Flat Bottom - No Handle - White #16
# Paper Bags - Flat Bottom - No Handle - White #2
# Food Container - Disposable - Deli Container - Hinged (Clamshell) - Tamper Resistant
# Bread Bags
# Brush - Coffee Decanters - Pots - Urns - Dispensers
# Fruit Containers and Lids
# Butane Lighters
# Carpet Cleaners
# Translucent Printed Cups
# Probe Wipes
# Shampoo and Conditioner
# Disposable Sushi Trays
# Snack Boxes
# French Fry Cartons
# French Fry Cups
# Print Cups
# Insert Cups
# Paper Bags - Flat Bottom with Flat Handle - Natural/Brown/Kraft
# Produce Bags
# Laundry or Garment Bags - Disposable
# Pallet Wrap
# Bags All Other Disposable
# Burger Bags
# Chicken - Poultry Bags
# Labels - Pre Printed (non Medical)
# Food Container - Disposable - Takeout Container - Dessert Box
# Laundry Bags - Non-Disposable - Racks
# Submarine Bags
# Beverage Service Ice Buckets
# Lidding Wrap or Film
# Salad Boxes
# Stripper - Floor
# Pipettes
# Protectant
# Smallwares Holders
# Flag Picks
# Spoon Straws
# Pie - Dessert Wedge
# Cone Cups
# Freezer Bag - Non Resealable
# Table Skirt - Disposable
# Shoes
# Water Containers
# Back Support
# Sponge Mops
# Parts & Accessories Excl Handles
# Drain Parts
# Bucket - Tub
# Waste - Refuse Receptacles
# Cutlery & Cutlery Sets Dispensers
# Band Saw Blades
# Sanitizer Compatible (Add Your Own Disinfectant) Wipers
# Delicate or Critical Task Wiper
# Cup Sealing Film
# Tea Filters
# Ashtray Sand
# Soup Cup Lids Disposable
# Labels - Kits
# Guest Soap Bars
# Shipping Mailers / Envelopes - Bubble / Padded
# Bubble Wrap
# Foil Food Bags
# Tortillas Bags
# Disposable Absorbent Tray Pads
# Electric Vacuums
# Tape - Shipping / Packing / Packaging / Sealing / Storage
# Wrapping Paper / Protective Wrap (not film)
# Tape - Painters
# Tape - Printed Message (Fragile, Caution, etc)
# Tape - Filament / Strapping
# Rope - General
# Step Stools
# Baby Changing Table Liners
# Tampons
# Infectious Waste Bags - Isolation Liners
# Plugs or Stoppers for Non-Disposable Cup Lids
# Gloves - Driver - Any Material
# Gloves - Leather
# Paper Towels
# Food Trays or Carriers - Disposable - French Fries
# Healthcare Cups - Mugs - Glasses and Lids
# Donut Box
# Barn Boxes
# Food Container - Disposable - Takeout Container - Baklava
# Squeegee Parts
# Envelopes - Clasp Closure
# Brush - Espresso
# Wine Carrier
# Garlic Presses
# Dough Retarding Pans and Lids
# Bar Speed Rails
# Soup Bowls Ovenware
# Food Container - Disposable - Takeout Container - Hamburger
# Coffee Bags
# Ice Cream Cartons - Tubs and Lids
# Gloves - Other or Unknown Blend / Hybrid - Unlined
# Paper Bags - Flat Bottom - No Handle - White #4
# Countertop Ice Bin Merchandiser - Cooler
# Disposable Food Pans with Lids
# Ink Cartridges THIS L4 NEEDS TO BE SPLIT INTO AT LEAST 8 L4s
# Floating Candles
# Picks
# Patient Care - Personal Hygiene Wipes
# Knife Oil for Sharpening
# Basket Liner
# Table Covers - Flats
# Countertop Milk Coolers
# Wine - Ice Buckets w -  Stand
# Countertop Toasters & Parts - Conveyor
# Coveralls - Protective Overalls
# Rulers & Tape Measures
# Food Container - Disposable - Takeout Box - Single Compartment
# Rib Box
# Hot Drink Cups with Lids
# Baking Cups
# Seating Parts and Accessories
# Floorstanding Under Counter Refrigerators
# Mixed Bulk Cutlery
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft #1
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft #3
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft #5
# Countertop Ice Machines
# Table Skirting
# Countertop Oven Parts and Accessories
# Floorstanding Refrigerator - Freezer Combos
# Countertop Refrigerator - Freezer Combos
# Dispenser Holders - Organizers
# Cotton Swab
# All Purpose - Multi Purpose Disposable Towels
# Aspirin & All Other OTC Drug Store Products
# Hand Dryer (Wall Mounted)
# Glue
# Paint and Marking Supplies
# Ladders
# Detergent - Laundry - Powder - Single Load
# Vacuum Parts
# Sanitary Items
# Razors
# Hot - Cold Packs
# Waste Lids
# Broom Dust Pan Combo
# Weed Killer
# Entry Mats
# Tank Sprayer
# Floor Runners
# Glass Towels
# Label Maker Tape and Cartridges
# Vacuum Bags - Disposable
# Truck - Dolly Parts
# Dust Wipers
# Toilet Automatic Cleaners - Deodorizers
# Sweeper Cloths - Dry
# Bathroom Towels - Cloth
# File Storage Boxes and Totes
# Grabber - Reacher - Picker
# Adhesive Remover
# Office Storage Bags
# Bar Rags & Cloths
# Toothbrushes
# Floor Machines
# Sorter - Alpha Numeric
# Hair Spray - Mousse - Anti-Frizz - Oil and Gel
# Brush Broom Squeegee All In One
# Boot and Shoe Brush
# Medical Equipment
# Sealant
# Instruments & Accessories - Medical
# Scratch Coverer - Furniture
# Cutting Board Restorer - Cleaner
# Air Purifier
# Rechargable Cordless Vacuums
# Guest Foot File
# Side Open Waste Container
# Laundry Sanitizer - Disinfectant
# Detergent - Glass
# Fans (Not Kitchen)
# Cellulose Sponges
# Production Tables - Parts & Accessories
# Humidifiers and Parts
# Space Heaters
# Patio Heaters
# Handle Squeegee
# Headsets - Earphones - Earbuds
# Microphones
# Cushions
# Paper - Specialty (Resume / Stationary / Cardstock / Parchment (not kitchen parchment) / Misc
# Two Way Radios
# Brush Handle
# Healthcare Sharps Container & Accessories
# Floor Dryer
# Security Units - Carts
# Sanitary Napkin Bag
# Laundry Bags - Non-Disposable
# Safes - Vaults - Key Cabinets - Cash Lock Boxes
# Ramp Mats
# Floor Anti Slip Strips
# Calendars and Bases
# Desk Pads
# Writing - Legal - Steno - Memo - Note Pads
# Paper Fasteners (not clips)
# Folders - Classification / Fastener Type
# Binder Clips
# Magnetic or Adhesive Clips
# Paper Clips
# Staplers - Staple Removers and Staples
# Scissors
# Pencil Sharpeners
# Letter Openers
# Keyboards and Mouses
# Cable and Cord Organizers
# Pallet Bands
# Envelopes - Gummed Closure - #10 Size
# Content Indicator Signs and Socks
# Gloves - Foam Coated
# Gloves - Other Blend / Hybrid
# Gloves - Neoprene - Flock Lined
# Desk Organizer - Letter / Mail / Document
# Pen/Pencil Holder
# Business Card Holder / File / Box / Binder / Etc
# Bookends
# File Sorter - Stadium - Incline - Vertical - Wire or Box Style
# Projector Lamp Bulb
# Computer Accessories
# Mouse Pads
# Wrist Bands
# Name - Identification Tags - Adhesive and Inserts
# Printer and Printer Parts and Accessories (POS Type Only)
# Labels - FIle Folder
# Labels - Mailing / Postage / Shipping
# Labels - Multi Use Blank
# Highlighters
# Key Tags and Chains
# Index Tabs
# Shipping Tags
# Identification Badge Holders - Lanyards and Reels
# Labels - Thermal Transfer Multipurpose
# Pens
# Tent Cards - Scored for Printer
# Seals
# Labels - Chemical Resistant
# Stickers (Special Shapes, Words, Characters, etc)
# Planners
# Envelopes - Reusable Poly
# Clear Sleeves
# Folders - Expansion
# Office Supplies - Holders - Organizers
# Desk Tray - For Accessories
# Travel ID Holder
# Folders - File Pockets
# Magnifiers
# Identification Cards
# Pencil - Colored
# Adapters (for Electronics)
# Charging Station
# Cable and Cord Ties
# Write On Boards - Signs
# Hammers and Mallets
# Tool Kits
# Laminator Machine
# Tubes (Shipping and Carrying)
# Paper - Fax
# Label Makers and Guns
# Toner Cartridges
# Bulletin Board - Cork
# Bulletin Board - Magnetic
# Easel
# Bulletin Board - Fabric
# Paper - Copy and Printing - Color
# Memory Card
# Tape - Decorative
# Chalk
# Presentation Boards
# Folder - Project File
# Folders - File Jackets
# Coin Wrappers
# Money Counting - Handling - Organizing Products
# Counterfeit Detection
# Calculators
# Paper - Wide / Large Format - All Types
# Paper - Photo / Fine Art
# Multi-Use Gloves
# Freezer Gloves
# Tape - Electrical / Vinyl
# File - Horizontal Tray Type
# Stretch Film (Shipping and Packaging)
# Shipping Mailers / Envelopes - Poly
# Shipping Mailers / Envelopes - Rigid / Corrugated
# Markers - Permanent
# Envelope Moistener
# Markers - China
# Compressed Gas Duster
# Tape - Double Sided
# Mounting Putty
# Batteries - AA
# Batteries - AAA
# Batteries - Coin and Button Style
# Batteries - Hearing Aid
# Batteries - D
# Batteries - C
# Business Cards
# Bandanas - Headbands and Scarfs
# Clips - Bulldog
# Cutting Mats
# Battery Chargers
# Shredders and Shredder Parts
# Telephone Stand
# Wrist Pads / Rests
# Light Bulbs - Incandescent
# Light Bulbs - Halogen
# Light Bulbs - LED
# Flourescent Bulbs
# Light Bulbs - Flood (Inside)
# Thumbtacks and Push Pins
# Flash Drives
# Bulletin Board - Vinyl
# Power Tools (Drills - Saws - Sanders - etc)
# Pliers
# Hearing Protection - Earmuffs
# Cash Register
# Admission Tickets and Bands
# Gloves - Other or Unknown Blend / Hybrid - Lined
# Gloves - Spandex
# File - Desktop Drawers
# Coat - Lab
# Adhesive Covering (AKA Contact Paper or Shelf Liner)
# Shipping Mailers / Envelopes - Snap Pack
# Picture Hanging Strips - Removable / Repositionable
# Tape - Write On (Chalkboard or Dry Erase, etc)
# Tape - Adhesive Tape Runner / Roller
# Page Flags
# Tape - Label Protection
# Tape - Book
# Tape - Adhesive Transfer Tape
# Fasteners - Hook and Loop (Velcro, etc)
# Labels - Pricing Guns
# Envelopes - Gummed Closure - Other Sizes
# Envelopes - Self Adhesive / Redi Strip - #10 Size
# Fasteners - For Folders
# Presentation Tablets or Pads
# Folders - Hanging
# Portable Document Organizer with Closure
# Expansion Organizer (Not Folders)
# Envelopes - String and Button
# Gloves - Nylon
# Paper Cutter
# Shipping Edge Protectors
# Notice Boards
# Security Check Paper
# Cork Panels and Rolls (not Bulletin Boards)
# Time Clocks - Time Keeping Devices and Accessories
# Bulletin Board - Foam
# Envelopes - Greeting Card / Invitation
# Envelopes - Window
# Shipping Mailers / Envelopes - Catalog
# Envelopes - Fold Flap Ungummed
# Shipping Mailers / Envelopes - Expansion
# Shipping Mailers / Envelopes - DVD / CD
# Envelopes - Attorney / Transport Case File
# Shipping Mailers / Envelopes - Tamper Evident
# Rust and Hard Water Stain Remover
# Coat - Rain
# Stages - Risers
# Labels - Coat Check
# Folder Dividers
# Extension Cords
# Labels - Medical
# File Pocket Handles
# Portion Cups
# Hand Sinks
# Caviar Spoon
# Tableservice Cone Holder
# Rinse Aid - Warewashing - Machine
# Boards for Display or Presentation Boxes
# Sub Box
# Boning Knife
# Santoku Knife
# Mixing Whisks
# Outdoor Umbrella Base
# Fuel Lamps
# Kids Cups - Non Disposable
# Tea Lights
# Drip Tray
# Undercounter Dishwasher Parts
# Wall Racks
# 1-Copy Guest Checks
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft 1/4 BBL
# Jars
# Sharpeners
# Stein
# Equipment Guards
# Food Container - Disposable - Takeout Container - Pastry Box
# Twist Ties
# Paper Bags - Flat Bottom - No Handle - White #14
# Paper Bags - Flat Bottom - No Handle - White #3
# Japanese Knife
# Fillet Knife
# Holding Thermometers
# Gas Connectors Kits - Parts - Accessories
# Food Handling Gloves
# Salt Mills - Grinders
# Egg - Hashbrown Rings
# Water Softener
# Cutting Board Stand
# Steak Knife
# Sifters
# Labels - Numeric (Non Date Related)
# Tableservice Bowls - Adaptive
# Cups - Lids and Mugs - Adaptive
# Tray Tickets
# Grill Planks
# Pint Draft Glasses
# Basket Liners
# Temperature Recording Station
# Glove Racks
# Liquor Pourer Cover
# Uniform Shirts
# Machine Oils & Lubricants - Floorstanding Appliances
# Fryer Brush
# Labels - Sanitizer Related
# Blenders
# Carry Out - To Go - Tamper Resistant Bags
# China Caps
# Floorstanding Display Refrigerators
# Floss
# Chefs - Cook Shirts
# Chefs Pants
# Bottle Stopper - Wine
# Fryer Basket Accessories
# Paella Pan
# Bakery Molds Liners
# Tableservice Tortilla Servers
# Cimeter Knife
# Thermometer Sanitizer Tanks and Tank Holders
# Food Warmer - Drawer Style
# Escargot Forks
# Dish - Pot Pie Ovenware
# Floor Scraper
# Prep Table with Refrigerated Base and Parts
# Floorstanding Fryer Parts and Accessories
# Tableservice Salad Service Ladles - Dressing
# Gel Fuel
# Dining Area Tables
# Countertop Ice Bin
# Foot or Forearm Door Opener
# Booster Seats
# Buffet Service Covers - Domes
# Meat Grinders
# Lollipop or Cake Pop Treat Sticks
# Chocolate Molds
# Chocolate Melter
# Wet Mops - Clamp
# Seafood Trays
# Countertop Induction Charger - Base Heater
# Party Kits
# Tablecloths Non Disposable
# Straw Dispensers
# Countertop Countertop Fryers
# Floorstanding Refrigerator Parts and Accessories
# Cover and Skirt Accessories
# Saute Pan
# Cheese Knife
# Mop Handle Color Sleeves
# Party Centerpiece
# Ice Cream Makers
# Tableservice Taco Servers - Holders
# Custom Print Guest Checks
# Chairs
# Butcher Block
# Dining Area Table Tops
# Dining Area Table Bases
# Sushi Roller
# Pizza Knife
# Equipment Stand Tables
# Floorstanding Mixers Parts and Acessories
# Compartment Sinks
# Tie
# Can Racks
# Drop In Sinks
# Coat Hooks
# Countertop Conveyor Ovens
# Food Warmer - Heated Shelf / Tray Style
# Buffet Service Table Tents - Card Holders
# Tape - Safety
# Floorstanding Convection Ovens
# Floorstanding Chest Freezer
# Floorstanding Ice Bin Parts & Accessories
# Floorstanding Oven Parts and Accessories
# Floorstanding Ice Machine Parts - Accessories
# Salad - Cold Food Bars
# Beverage Station - Counter and Parts
# Carrier Parts
# Food Warmer - Soup / Kettle Style
# Keg Racks
# Station - Counter - Hot
# Blenders - Stand - Culinary Use
# Pasta Machines
# Blender Parts - Stand and Stick - Culinary Use
# Underbar Sinks
# Menu Boards
# Bag Opener
# Butler - Waiter Gloves
# Floorstanding Walk-In Refrigerators Parts & Accessories
# Pasta Machine Parts and Accessories
# Countertop Lettuce Crisper
# Patty Press
# Food Warmer - Bun
# Floorstanding Upright Refrigerators
# Ice Cube or Ball Trays
# Countertop Crepe Maker
# Order Wheel
# Tooth Pick Dispensers
# Dough Wheels - Dockers
# Electric Can Openers & Parts
# Buffet Service Lids - Covers For Crocks
# Tea Brewers
# Grease Traps and Parts
# Drainboard Cabinets
# Sheet Pan Extender
# Countertop Manual Bag Sealer (non Vacuum)
# Popcorn Machine - Floorstanding
# Electric Slicers - Cutters
# Floorstanding Smoker Ovens
# Confectionary Funnel
# Floorstanding Ranges Parts and Accessories
# Juicer Parts
# Room Service Table - Cart
# Healthcare Bases - Unitized
# Countertop Ice Machine Parts - Accessories
# Spoon Rests
# Pie Knife
# Mop Sinks
# Stock Pot Covers
# Wall Clocks
# Food Warmer - Heat Lamps
# Sink Disposer and Parts
# Facial Tissue Dispensers
# Grill - Griddle Squeegees and Blades
# Floorstanding Floor Standing Fryers
# Steam Table Parts and Accessories
# Clam Knives
# Cabinet Parts and Accessories
# Biscuit Cutters
# Ice Cream Server and Parts
# Puree Food Molds
# Adaptive Flatware
# Foam Tubing - Adaptive
# Spherification Tool
# Infant - Toddler Flatware
# Tableservice Spoons - Adaptive
# Scrap Block
# Test Strip Dishwasher Thermometers
# Bar Pour Test Kits
# Tableservice Salad Service Caddy - Crock
# Grill Thermometers
# Specialty Knife
# Butcher Knife
# Griddle Server Ovenware
# Water Pan - Spill
# Metal Skewers
# Paper Towel Dispenser
# Food Container - Disposable - Pillow Pack
# Pastry Tube
# Lighter Fuel General
# Outdoor Chairs - Benches
# Biohazard Response KIt
# Microfiber Cloth Wipers - Disposable
# Countertop Fryer Parts and Accessories
# Bedding
# Catering Box - Corrugated with Integrated Lid
# Hood Vent Parts
# Coffee - Tea Canisters
# Uniform Pants
# Gloves - Poly - Powdered
# Paper Bags - Flat Bottom - No Handle - White #5
# Milkshake
# Fryer Thermometers
# Spice Racks
# Floorstanding Ice Machines
# Beverage Service Sugar Bowls
# Bathroom Partitions and Accessories
# Display Case Parts
# Plate Guard - Adaptive
# Dish - Custard Ovenware Incl Creme Brulee
# Pastry Set
# Placemat - Napkin Combo
# Mat Connectors
# Food Wrap
# Garnisher
# French Press
# Syringes
# Vegetable - Produce Knife
# Oven Paddles
# Tableservice Skewer Holders
# Cutting Board Allergen Wall Chart
# Ham Stand for Cutting
# Pans - Non Specific
# Floorstanding Ice Bin
# Carving Knife
# Floorstanding Ranges
# Channel Knife
# Matches Book Plain
# Popover Pan
# Lawn and Leaf Bags
# Paper Bags - Flat Bottom - No Handle - White Size Unspecified
# Ice Cream Cone Holders
# Salt Lamp
# Drainboards
# Dough Sheeter and Parts
# Knives Carrying Case
# Cookie Cutters
# Floorstanding Under Counter Freezers & Parts - Accessories
# Floorstanding Steamers and Parts
# Sauce Guns - Funnels
# Food Grinder Parts and Accessories
# Station - Counter Hot and - or Cold
# Floorstanding Cook and Hold Ovens
# Floorstanding Draft Beer Cooler
# Bar Stools
# Vacuum Bags - Non-Disposable
# Bar Beakers - Flasks
# Candy Boxes
# Floorstanding Walk-In Refrigerator - Freezer Combos
# Dry Food Dispenser
# Pizza Bubble Popper
# Floorstanding Display Freezers
# Floorstanding Tilt Skillet - Braising Pan Parts & Accessories
# Floorstanding Combi Ovens
# Floorstanding Horizontal Refrigerators - Slide Top or Front Doors
# Disposable Cupcake Stand
# Floorstanding Freezers All Other Parts & Accessories
# Stir Stick Dispensers
# Outdoor Tables
# Tray Dispenser
# Corkscrew
# Floorstanding Display Refrigerators Parts & Accessories
# Paper - Plastic Cake Toppers
# Station - Counter - Cold
# Floorstanding Glass Frosters
# Floorstanding Walk-In Freezers Parts & Accessories
# Table Covers - Rolls
# Steam Kettle Parts
# Fork Pick
# Talcum Powder
# Knife Covers
# Booths
# Menu Extras
# Countertop Refrigerators All Other
# Reservation Forms - Books
# Floorstanding Broilers
# Floorstanding Ice Bin Merchandiser - Cooler
# Outdoor Umbrellas
# Illuminated Signs
# Countertop Grills
# Refrigiwear Jackets
# Baby Changing Table Replacement Parts
# Lecterns and Podiums and Parts
# Floorstanding Ice Cream Freezers
# Waste Container Cover (NOT lid)
# Floorstanding Walk-In Refrigerators
# Countertop Display Refrigerators
# Outdoor Table Tops
# Stanchion Ropes
# Display Bin with Door
# Kitchen Tweezers
# Thermostat
# Rice Cooker Parts
# Syrup Warmers
# Pass Thru Shelf
# Shipping Crate
# Countertop Tortilla Press
# Production Clothespins
# Suction Cup Lifter
# Waste Cabinets
# Mousse Ring
# Cart - Insulated Pan Carrier
# Floorstanding Pizza Ovens
# Production Food Storage Container Pour Lids
# Pizza Stone
# Pager Parts And Accessories
# Floorstanding Grills
# Sake Cup
# Cart - Insulated Meal Delivery
# Floorstanding Refrigerators All Other
# Smoking Gun
# Wireless Pagers
# Cheese Melters and Parts
# Countertop Refrigeration Systems
# Cup Carrier Dispensers
# Floorstanding Walk-In Freezers
# Floorstanding Tilt Skillet - Braising Pan
# Shovel for Oven Ash
# Flameless Heat Packs
# Cookbooks
# Vacuum Sealer Machine Parts
# Floorstanding Milk Coolers
# Soda Gun Holder
# Bakery Decorating Tool
# Food Warmer - French Fry
# Tableservice Salad Service Dish - Gravy - Sauce
# Sinks
# Floor Mat Racks
# Lids (Unspecified type - kind)
# Table Skirting - Hanger
# Countertop Pizza Dough Press
# Knife Sharpener - Electric
# Crepe Pan
# Floorstanding Fryer Covers
# Security Mirrors
# Wok Shovel
# Knife Guard
# Oil - Shortening Quality Test Strip
# Buffet Tables
# Outdoor Table Bases
# Textile Napkins - Custom - Logo
# Waffle Iron Parts and Accessories
# Floorstanding Grate Grills
# Pressure Cooker
# Rice Mixing Tub
# Scales Accessories
# Countertop Grill Parts and Accessories
# Non-Disposable Service Container Lids
# Napkin and Straw Dispenser
# Countertop Combi Ovens
# Dump Sinks
# Fan Parts
# Gloves - Neoprene - Unlined
# Peg Board
# Production Squeeze Out Dispensers Cap - Cover
# Cake Tester
# Soup Container Handle
# Floorstanding Stove Parts and Accessories
# Shirred Egg Ovenware
# Make Up Removal Wipes
# Table Pads
# Floorstanding Griddles
# Diaper Rash Creams and Ointments
# Party Tray Bags
# Countertop Ice Bin Parts & Accessories
# Air Freshener - Odor Control - Wax Melts
# HPP Juice Kegs
# Facility - Decor
# Napkin - Size & Shape Unspecified
# Paper Bags - Flat Bottom - No Handle - White 1/8 BBL
# Sausage Stuffer
# UV Sterilizer - Sanitizer
# Ink
# Body Oil
# Paper Bags - Flat Bottom - No Handle - White 1/6 BBL
# Safety - Health - Exam Gloves
# Denture Adhesive
# Paper Bags - Flat Bottom - No Handle - Natural/Brown/Kraft Size Unspecified
# Personal Lubricant
# Shakers - Bottles and Lids
# Cleaner - Engine
# Contact Lense Drops
# Doilies - Lace
# Gloves - Not Further Specified
# Cleaner- Glass Cooktop
# Utility Knife
# Tap - Draft Handles
# Cleaner - Popcorn Kettle
# Toothbrush - Prepasted DIsbosable
# Office and Task Chairs
# Notebooks
# Printers - Office (Not POS)
# Hard Drive - External Portable
# Burner - Propane or Natural Gas
# Battery Backup / UPS AVR / Surge Devices
# Hard Drive - Internal
# T-Shirts
# Tape - Foil
# Light Bulbs - Flourescent
# Napkin As Cutlery Sleeve
# Battery - 12 Volt
# Shot Glasses Test Tube
# Televisions
# Cart - Insulated Electric
# Insulated Carriers - Electric
# Insulated Carrier Temperature Barrier
# Chalk - Black Board
# Labels - Subwrap

# %%
sample_test = sample[sample['L4_dictionarySubgroup']=='Spoon Rests']
sample_test.head()
# Out:
#        L3_Dictionary_SubCategory L4_dictionarySubgroup  \
# 64978   Ladles - Spoons - Scoops           Spoon Rests
# 85186   Ladles - Spoons - Scoops           Spoon Rests
# 85284   Ladles - Spoons - Scoops           Spoon Rests
# 89536   Ladles - Spoons - Scoops           Spoon Rests
# 110332  Ladles - Spoons - Scoops           Spoon Rests
#
#                                                  ProdName
# 64978                  REST, SPOON 8.75 S/S MIRROR FINISH
# 85186              Spoon Rest, 9X4 Charcoal Ceramic China
# 85284              SPOON REST, UTENSIL 3X5 S/S HEAVY-DUTY
# 89536   SPOON REST, UTENSIL 9X3.75X1.5 S/S BRUSHED FINISH
# 110332    Spoon Rest, 4 Kyoto Euro White Porcelain China"

# %% [markdown]
# ### **Lable preprocessing Function**

# %% [markdown]
# This will remove the unwanted parts from the predicted lable and return the lable in much readable manner

# %%
prediction = model.predict(text)
print(prediction[0][0])

# %%
# This function process the prediction by getting the input
def get_lable(text):
  # Processing the text
  text = preprocess(text)
  # Get the prediction
  prediction = model.predict(text)
  return prediction[0][0]

# %%
from_func = get_lable(text)
print(from_func)

# %%
# Function to preprocess the lable
def label_processing(label):
  label = re.sub('__label__', '', label)
  label = re.sub('_', ' ', label)
  label = re.sub(' +', ' ', label)
  return label.strip().lower()

# %%
print(label_processing(from_func))
